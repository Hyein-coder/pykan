# %% [markdown]
# # Example 3: Deep Formulas
#
# The orignal Kolmogorov-Arnold theorem says that it suffices to have 2-Layer function composition (inner and outer functions), but the functions might be non-smooth or even fractal. We generalize KA representation to arbitrary depths. An example a 2-Layer KAN (with smooth activations) is unable to do is: $f(x_1,x_2,x_3,x_4)={\rm exp}({\rm sin}(x_1^2+x_2^2)+{\rm sin}(x_3^2+x_4^2))$, which requires at least 3-Layer KANs.

# %% [markdown]
# ### Three-layer KAN

# %%
from kan import *

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

# create a KAN: 2D inputs, 1D output, and 5 hidden neurons. cubic spline (k=3), 5 grid intervals (grid=5).
model = KAN(width=[4,2,1,1], grid=3, k=3, seed=1, device=device)
# f = e^(((sin(x^2+y^2) + sin(z^2+w^2))/2)
f = lambda x: torch.exp((torch.sin(torch.pi*(x[:,[0]]**2+x[:,[1]]**2))+torch.sin(torch.pi*(x[:,[2]]**2+x[:,[3]]**2)))/2)
dataset = create_dataset(f, n_var=4, train_num=3000, device=device) # d원래 학습샘플은 1000개인데 3000개로 조정

# train the model
model.fit(dataset, opt="LBFGS", steps=20, lamb=0.002, lamb_entropy=2.);   # 여기 lamb 랑 lamb_entropy 는 자세히 들여다보기 using ctrl+좌클릭
# Out:
# cpu
# checkpoint directory created: ./model
# saving model version 0.0
# | train_loss: 3.04e-01 | test_loss: 3.08e-01 | reg: 1.10e+01 | : 100%|█| 20/20 [00:16<00:00,  1.20it
# saving model version 0.1

# %%
model = model.prune(edge_th=1e-2)
model.plot()
# Out:
# saving model version 0.2

# %%
grids = [3,5,10,20,50]
#grids = [5]

train_rmse = []
test_rmse = []

for i in range(len(grids)):
    #model = KAN(width=[4,2,1,1], grid=grids[i], k=3, seed=0, device=device).initialize_from_another_model(model, dataset['train_input'])
    model = model.refine(grids[i]) # 0~4
    # 각각 50 step 실행할동안 20 step 이후에는 grid 고정해 더 이상 그리드 위치 바꾸기 X 고정된 그리드 위에서 스플라인 계수만 조정함으로 더 안정적으로 미세 조정
    results = model.fit(dataset, opt="LBFGS", steps=50, stop_grid_update_step=20); 
    train_rmse.append(results['train_loss'][-1].item())
    test_rmse.append(results['test_loss'][-1].item())

    # 각 train_rmse 와 test_rmse에 5개의 원소가 할당됨(grid가 각각 3 5 10 20 50 일 때의 loss 값)
# Out:
# saving model version 0.3
# | train_loss: 2.98e-01 | test_loss: 3.03e-01 | reg: 1.14e+01 | : 100%|█| 50/50 [00:26<00:00,  1.87it
# saving model version 0.4
# saving model version 0.5
# | train_loss: 2.73e-01 | test_loss: 2.96e-01 | reg: 1.08e+01 | : 100%|█| 50/50 [00:28<00:00,  1.75it
# saving model version 0.6
# saving model version 0.7
# | train_loss: 2.30e-01 | test_loss: 2.61e-01 | reg: 1.10e+01 | : 100%|█| 50/50 [00:28<00:00,  1.75it
# saving model version 0.8
# saving model version 0.9
# | train_loss: 2.09e-01 | test_loss: 2.41e-01 | reg: 1.11e+01 | : 100%|█| 50/50 [00:36<00:00,  1.38it
# saving model version 0.10
# saving model version 0.11
# | train_loss: 1.89e-01 | test_loss: 2.47e-01 | reg: 1.12e+01 | : 100%|█| 50/50 [00:38<00:00,  1.30it
# saving model version 0.12

# %%
print(train_rmse)
print(test_rmse)
# Out:
# [0.29750949144363403, 0.2733207046985626, 0.2296544760465622, 0.20940294861793518, 0.18871229887008667]
# [0.3034108877182007, 0.2955250144004822, 0.2614615261554718, 0.2407456338405609, 0.24674546718597412]

# %%
model.plot()

# %% [markdown]
# Author's note: The scaling isn't optimal. Possibly because of updates on curve2coef, to be investigated.

# %%
import numpy as np
import matplotlib.pyplot as plt

n_params = np.array(grids) * (4*2+2*1+1*1)
plt.plot(n_params, train_rmse, marker="o")
plt.plot(n_params, test_rmse, marker="o")
plt.plot(n_params, 10000*n_params**(-4.), color="black", ls="--")
plt.legend(['train', 'test', r'$N^{-4}$'], loc="lower left")
plt.xscale('log')
plt.yscale('log')
print(train_rmse)
print(test_rmse)
# Out:
# [0.29750949144363403, 0.2733207046985626, 0.2296544760465622, 0.20940294861793518, 0.18871229887008667]
# [0.3034108877182007, 0.2955250144004822, 0.2614615261554718, 0.2407456338405609, 0.24674546718597412]

# %% [markdown]
# ### Two-layer KAN
#
# Now we show that a 2 two-layer KAN performs much worse for this task

# %%
from kan import KAN, create_dataset
import torch

# create a KAN: 2D inputs, 1D output, and 5 hidden neurons. cubic spline (k=3), 5 grid intervals (grid=5).
model = KAN(width=[4,9,1], grid=3, k=3, seed=0)
f = lambda x: torch.exp((torch.sin(torch.pi*(x[:,[0]]**2+x[:,[1]]**2))+torch.sin(torch.pi*(x[:,[2]]**2+x[:,[3]]**2)))/2)
dataset = create_dataset(f, n_var=4, train_num=3000)

# train the model
model.fit(dataset, opt="LBFGS", steps=20, lamb=0.002, lamb_entropy=2.);
model.plot(beta=10)
# Out:
# checkpoint directory created: ./model
# saving model version 0.0
# | train_loss: 8.73e-02 | test_loss: 9.09e-02 | reg: 1.34e+01 | : 100%|█| 20/20 [00:15<00:00,  1.33it
# saving model version 0.1

# %%
grids = [3,5,10,20,50]

train_rmse = []
test_rmse = []

for i in range(len(grids)):
    #model = KAN(width=[4,9,1], grid=grids[i], k=3, seed=0).initialize_from_another_model(model, dataset['train_input'])
    model = model.refine(grids[i])
    results = model.fit(dataset, opt="LBFGS", steps=50, stop_grid_update_step=30);
    train_rmse.append(results['train_loss'][-1].item()) # item은 .item()**은 하나의 값만 있는 PyTorch 텐서(Tensor)에서 순수한 파이썬 숫자(number)를 추출
    test_rmse.append(results['test_loss'][-1].item())

    # 이렇게 되면 train_rmse 와 test_rmse 에는 grid 3,5,10,20,50에 해당하는 loss 값들이 나온다
# Out:
# saving model version 0.2
# | train_loss: 7.24e-02 | test_loss: 7.76e-02 | reg: 1.71e+01 | : 100%|█| 50/50 [00:32<00:00,  1.53it
# saving model version 0.3
# saving model version 0.4
# | train_loss: 5.70e-02 | test_loss: 6.53e-02 | reg: 1.80e+01 | : 100%|█| 50/50 [00:31<00:00,  1.57it
# saving model version 0.5
# saving model version 0.6
# | train_loss: 4.66e-02 | test_loss: 5.74e-02 | reg: 1.81e+01 | : 100%|█| 50/50 [00:33<00:00,  1.47it
# saving model version 0.7
# saving model version 0.8
# | train_loss: 3.81e-02 | test_loss: 5.43e-02 | reg: 1.81e+01 | : 100%|█| 50/50 [00:42<00:00,  1.16it
# saving model version 0.9
# saving model version 0.10
# | train_loss: 3.05e-02 | test_loss: 5.47e-02 | reg: 1.81e+01 | : 100%|█| 50/50 [01:12<00:00,  1.44s/
# saving model version 0.11

# %%
import numpy as np
import matplotlib.pyplot as plt

n_params = np.array(grids) * (4*9+9*1)
plt.plot(n_params, train_rmse, marker="o")
plt.plot(n_params, test_rmse, marker="o")
plt.plot(n_params, 300*n_params**(-2.), color="black", ls="--")
plt.legend(['train', 'test', r'$N^{-4}$'], loc="lower left")
plt.xscale('log')
plt.yscale('log')
print(train_rmse)
print(test_rmse)
# Out:
# [0.07235579937696457, 0.0569952130317688, 0.046631891280412674, 0.03808952495455742, 0.03053107298910618]
# [0.07761067152023315, 0.0652594342827797, 0.05744369328022003, 0.054259635508060455, 0.054687414318323135]

# %%
# 왜 layer = 2 인것이 layer = 3 인것보다 더 error 가 적게 나오지...????
