# %% [markdown]
# MLP 이용 간단한 ANN을 만들어서 데이터석 진행 (KAN 비교용)

# %% [markdown]
# step1. Excel 데이터 가져오기

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import os
import numpy as np

filepath = r"C:\Users\kepco201\Desktop\KAN_python\pykan-master\github\workflows\TaeWoong\25.01.14_CO2RR_GSA.xlsx" # 엑셀 데이터 로드
xls = pd.ExcelFile(filepath)    # pd.ExcelFile(경로) --- path에 있는 엑셀파일을 읽는다


df_in = pd.read_excel(xls, sheet_name='Input')    # pd.read_excel 함수를 통해 수치형 데이터를 읽어온다
df_out = pd.read_excel(xls, sheet_name='Output')     # df_in = 입력 데이터  //  df_out = 출력 데이터


print("=== 데이터 타입 확인 ===")     
print("Input 데이터 타입:")
print(df_in.dtypes)      # .dtypes = 데이터 타입
print(f"Input 데이터 형태: {df_in.shape}")   # .shape = 데이터 행열 구조


selected_columns = [                      
    "Current density (mA/cm2)", 
    "Faradaic efficiency (%)", 
    "CO coversion",
    "Voltage (V)", 
    "Electricity cost ($/kWh)", 
    "Membrain cost ($/m2)",
    "Catpure energy (GJ/ton)", 
    "Crossover rate"
]


X = df_in[selected_columns].copy()      # 데이터[ 필요한 열 이름] 2501 * 정수 형태로 나올 것이다



# Y 데이터 선택 
Y = df_out[['MSP ($/kgCO)']].values.reshape(-1, 1)  # MSP ($/kgCO)  # Required energy_total (MJ/kgCO) 
# 왜 reshape(-1. 1)을 하는것? --- 

print(f"\n=== 최종 데이터 형태 ===")
print(f"X 형태: {X.shape}")
print(f"Y 형태: {Y.shape}")
print(f"X 컬럼: {X.columns.tolist()}")
# Out:
# === 데이터 타입 확인 ===
# Input 데이터 타입:
# Current density (mA/cm2)    float64
# Faradaic efficiency (%)     float64
# CO coversion                float64
# Voltage (V)                 float64
# Electricity cost ($/kWh)    float64
# Membrain cost ($/m2)        float64
# Catpure energy (GJ/ton)     float64
# Crossover rate              float64
# Unnamed: 8                  float64
# Unnamed: 9                   object
# Unnamed: 10                  object
# Unnamed: 11                  object
# Unnamed: 12                 float64
# Unnamed: 13                  object
# Unnamed: 14                 float64
# Unnamed: 15                  object
# Unnamed: 16                 float64
# Unnamed: 17                  object
# Unnamed: 18                 float64
# Unnamed: 19                 float64
# Unnamed: 20                  object
# dtype: object
# Input 데이터 형태: (2501, 21)
#
# === 최종 데이터 형태 ===
# X 형태: (2501, 8)
# Y 형태: (2501, 1)
# X 컬럼: ['Current density (mA/cm2)', 'Faradaic efficiency (%)', 'CO coversion', 'Voltage (V)', 'Electricity cost ($/kWh)', 'Membrain cost ($/m2)', 'Catpure energy (GJ/ton)', 'Crossover rate']

# %% [markdown]
# step2. 데이터 분리 및 스케일링 _ 여기서는 평균 0 표준편차 1로 스케일링함

# %%
# 1차 분할 (test 분리)
X_train_val, X_test, Y_train_val, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
# 2차 분할(train, valid 분리)
X_train, X_val, Y_train, Y_val = train_test_split(X_train_val, Y_train_val, test_size=0.2, random_state=42)

# train:valid:test = 64:16:20

# 데이터 스케일링

# **중요** : 스케일러는 반드시 *훈련 데이터(X_train)*에만 fit 해야한다. 그래야 valid나 test 데이터의 정보가 누출될 위험을 줄인다

scaler_X = MinMaxScaler(feature_range=(0.1, 0.9))
X_train_scaled = scaler_X.fit_transform(X_train)  # X_train 데이터를 이용해 scaler_X.transform을 학습 + X_train_scaled 반환
X_val_scaled = scaler_X.transform(X_val) # train 데이터로 학습한 scaler_X.transform 함수로 다른 것들도 학습
X_test_scaled = scaler_X.transform(X_test) 

scaler_Y = MinMaxScaler(feature_range=(0.1, 0.9))
Y_train_scaled = scaler_Y.fit_transform(Y_train)  # Y_train 데이터를 이용해 scaler_Y.transform을 학습 + Y_train_scaled 반환
Y_val_scaled = scaler_Y.transform(Y_val)
Y_test_scaled = scaler_Y.transform(Y_test)

# 분리한 결과 어떻게 나오는지 확인해보기

print("\n--- 데이터 분할 및 전처리 최종 결과 ---")
print(f"훈련 데이터 형태: X({X_train_scaled.shape}), Y({Y_train_scaled.shape})")
print(f"검증 데이터 형태: X({X_val_scaled.shape}), Y({Y_val_scaled.shape})")
print(f"테스트 데이터 형태: X({X_test_scaled.shape}), Y({Y_test_scaled.shape})")

print("\n\n 스케일링된 훈련 데이터(X_train_scaled) 샘플:")
print(pd.DataFrame(X_train_scaled, columns=X_train.columns).head())  
# .head()는 첫번째 5줄만 출력 , numpy 배열은 컬럼명이 없어 데이터 구조가 한눈에 파악하기 어렵다. 
# 그래서 pd.DataFrame(..., columns=...)을 이용하면, 스케일링된 데이터를 원래 컬럼명과 함께 보기 좋게 pandas DataFrame으로 변환 이용
# Out:
# --- 데이터 분할 및 전처리 최종 결과 ---
# 훈련 데이터 형태: X((1600, 8)), Y((1600, 1))
# 검증 데이터 형태: X((400, 8)), Y((400, 1))
# 테스트 데이터 형태: X((501, 8)), Y((501, 1))
#
#
#  스케일링된 훈련 데이터(X_train_scaled) 샘플:
#    Current density (mA/cm2)  Faradaic efficiency (%)  CO coversion  \
# 0                  0.828263                  0.58480       0.61872
# 1                  0.278703                  0.22768       0.43888
# 2                  0.533627                  0.51152       0.19600
# 3                  0.290552                  0.26896       0.81680
# 4                  0.870536                  0.20304       0.75568
#
#    Voltage (V)  Electricity cost ($/kWh)  Membrain cost ($/m2)  \
# 0     0.423009                  0.844618               0.38320
# 1     0.630772                  0.727131               0.78448
# 2     0.782193                  0.725210               0.22896
# 3     0.441577                  0.254302               0.37808
# 4     0.572509                  0.481273               0.10608
#
#    Catpure energy (GJ/ton)  Crossover rate
# 0                 0.686475         0.83824
# 1                 0.861265         0.89968
# 2                 0.634614         0.83760
# 3                 0.311605         0.55696
# 4                 0.673029         0.84368

# %% [markdown]
# step3. MLP(ANN) 구조 설계 및 여러 신경망 층 구조에 대한 GridSearchCV 진행을 통해 최적 구조 찾기

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense
from scikeras.wrappers import KerasRegressor  # scikeras 권장
from sklearn.model_selection import GridSearchCV






# 1. 모델 생성 함수 정의 / units1 = hidden layer 1층 / units2 = hidden layer 2층
def create_ann_model(units1=32, units2=16, activation='relu'):     
    model = Sequential([
        Input(shape=(8,)),             # 입력 특성 8개
        Dense(units1, activation=activation),  # hidden layer (units1)개
        Dense(units2, activation=activation),  # 입력 특성 8개 (units2)개
        Dense(1, activation='linear')
    ])
    
    
    model.compile(
        optimizer='adam',
        loss='mean_squared_error',   # loss function = MSE -- 이것에 따라 학습의 방향이 결정됨
        metrics=['mean_absolute_error']  # 학습에 영향은 주지 않지만 그냥 평가지표 MAE
    )
    return model  


# 2. 래퍼 정의 (scikeras)     
regressor = KerasRegressor(    # Keras로 만든 딥러닝 모델을 Scikit-learn의 회귀(Regressor) 모델처럼 보이게 포장 --- scikit-learn의 최적의 units 수 등을 찾는 gridsearchCV 같은 기능을 쓰기 가능
    model=create_ann_model,    
    verbose=0                  # verbose = 0 --- 모델 훈련과정 출력 X // 1 -- 출력  //  2 -- epoch 끝날때마다 출력
)



# 3. 모델 생성 및 구조 확인
# Required energy_total 예측 모델
#ann_model = create_ann_model()

# 모델의 구조를 요약하여 출력합니다.
#print("--- 'Required energy_total' 예측 모델 구조 ---")
#ann_model.summary()







# 4. GridSearchCV를 통해 검사할 놈들 결정 .. 나중에 GridSearchCV.fit()을 통해 학습 예정
grid = GridSearchCV(
    estimator = KerasRegressor( model=create_ann_model,verbose=0),   # Keras로 만든 딥러닝 모델을 Scikit-learn의 회귀(Regressor) 모델처럼 보이게 포장 --- scikit-learn의 최적의 units 수 등을 찾는 gridsearchCV 같은 기능을 쓰기 가능    
                                                                     # verbose = 0 --- 모델 훈련과정 출력 X // 1 -- 출력  //  2 -- epoch 끝날때마다 출력
    param_grid= {
        'model__units1': [16, 32],                    # hidden layer 1층 뉴런수 
        'model__units2': [8, 16],                     # hidden layer 2층 뉴런수
        'model__activation': ['relu', 'tanh'],        # 활성화함수
        'batch_size': [32],                           # 배치 사이즈
        'epochs': [100],                              # 학습 epoch 수  --- 총 학습 수 = 2*2*2 = 8 이다.
    },
    cv=3,                              # cross validation 3번 (3 fold validation)  --- 총 학습 수 = 8*3 = 24
    scoring='neg_mean_squared_error',  # -MSE가 높을수록 좋다고 설정
    n_jobs=-1                          # 사용 가능한 CPU 코어 전부 사용하라는 의미
)



grid_result = grid.fit(X_train_scaled, Y_train_scaled)   # GridSearchCV.fit() 실행하기 -- 여러 모델 구조 비교 --- 여러 정보가 grid_result에 할당이 됨


# 6. 결과 출력
print("최적 하이퍼파라미터:", grid_result.best_params_)
print("최적 평균 검증 MSE:", -grid_result.best_score_)  # 아까 score = -MSE로 정의함




# 7. 최적 파라미터 추출 / best_params에 저장되어 있는 최적 정보들 활용
optimal_units1 = grid_result.best_params_['model__units1']                   # best_params[키] = 밸류값 출력
optimal_units2 = grid_result.best_params_['model__units2'] 
optimal_activation = grid_result.best_params_['model__activation']
optimal_batch_size = grid_result.best_params_['batch_size']






# GridSearchCV.fit() 을 실행했을 때 과정
cv_results = pd.DataFrame(grid_result.cv_results_)  # 결과표를 pandas dataframe으로 변환 --- 그러면 보기 편함

print("\n=== GridSearchCV 상세 결과 ===")   
print(cv_results[['params', 'mean_test_score', 'std_test_score']].sort_values('mean_test_score', ascending=False)) # grid_result.cv_results_ 의 값 중 3개의 변수만 뽑아서 보기
# .sort_values =pandas.DataFrame을 특정 열의 값을 기준으로 재배치
#  mean_test_score을 기준으로 ascending=False: 내림차순 정렬 -- 성능이 가장 좋은 것이 위로 간다



# 9. 최적 모델 구조 보여주기
print(f"최적 모델 구조:8- {optimal_units1}-{optimal_units2}, activation: {optimal_activation}, -1")




# 7. (선택) 결과 table을 보기 좋게 정리
# import pandas as pd
# cv_results = pd.DataFrame(grid_result.cv_results_)
# display(cv_results.sort_values('mean_test_score', ascending=False))
# Out:
# 최적 하이퍼파라미터: {'batch_size': 32, 'epochs': 100, 'model__activation': 'relu', 'model__units1': 32, 'model__units2': 16}
# 최적 평균 검증 MSE: 0.0006198244214612355
#
# === GridSearchCV 상세 결과 ===
#                                               params  mean_test_score  \
# 3  {'batch_size': 32, 'epochs': 100, 'model__acti...        -0.000620
# 1  {'batch_size': 32, 'epochs': 100, 'model__acti...        -0.000821
# 2  {'batch_size': 32, 'epochs': 100, 'model__acti...        -0.000984
# 0  {'batch_size': 32, 'epochs': 100, 'model__acti...        -0.001037
# 7  {'batch_size': 32, 'epochs': 100, 'model__acti...        -0.001842
# 6  {'batch_size': 32, 'epochs': 100, 'model__acti...        -0.002166
# 5  {'batch_size': 32, 'epochs': 100, 'model__acti...        -0.002307
# 4  {'batch_size': 32, 'epochs': 100, 'model__acti...        -0.002803
#
#    std_test_score
# 3        0.000179
# 1        0.000291
# 2        0.000093
# 0        0.000119
# 7        0.000329
# 6        0.000524
# 5        0.000131
# 4        0.000201
# 최적 모델 구조:8- 32-16, activation: relu, -1

# %% [markdown]
# step4. 모델 학습 및 plot

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score
from tensorflow.keras.callbacks import EarlyStopping





def create_optimal_model():
    model = Sequential([
        Input(shape=(8,)),
        Dense(optimal_units1, activation=optimal_activation),
        Dense(optimal_units2, activation=optimal_activation),
        Dense(1, activation='linear')
    ])
    
    model.compile(
        optimizer='adam',
        loss='mean_squared_error',
        metrics=['mean_absolute_error']
    )
    return model

ann_model = create_optimal_model() # 100 epoch 기준 최적 모델 구조 생성




print("--- 모델 학습을 시작합니다 ---")  

early_stopping = EarlyStopping( # 최적 모델 학습 (Training)
    monitor='val_loss',         # 검증 손실 기준 = val_loss = validation set의 RMSE
    patience=20,                # 개선되지 않는 epoch 20회 동안 기다리기(8~20 추천)
    restore_best_weights=True   # 가장 좋은 가중치로 복원
)


history = ann_model.fit(
    X_train_scaled, 
    Y_train_scaled,
    epochs=1000, #충분히 큰 값으로 설정
    batch_size=optimal_batch_size, #  # GridSearchCV 결과 활용 --- 아까 32라고 정의
    validation_data=(X_val_scaled, Y_val_scaled),
    callbacks=[early_stopping],  # callback 중 1개인 Early_stopping 이용/ overfitting 뜨기 전에 earlystopping 으로 끊기
    verbose=1 # 각 epoch마다 진행상황 표현
)
print("\n--- 모델 학습 완료 ---")






 





# 3. 모델 성능 평가 (Evaluation)
print("\n--- 테스트 데이터 이용 모델 성능 평가 ---")
test_loss, test_mae = ann_model.evaluate(X_test_scaled, Y_test_scaled, verbose=0) # evaluate 함수 이용 / verbose = 0 이라 평과과정 출력 X / model을 compile 할 떄 정의한 loss 와 metrics 출력
print(f"테스트 데이터 손실 (MSE): {test_loss:.4f}")
print(f"테스트 데이터 평균 절대 오차 (MAE): {test_mae:.4f}")




# 예측한 값 출력
Y_pred_scaled = ann_model.predict(X_test_scaled)   # predict(입력변수) 함수는 모델의 출력값(예측값) 출력
Y_pred = scaler_Y.inverse_transform(Y_pred_scaled) # 역변환을 통해 Y_pred를 구함
Y_test_true = Y_test          # 가독성을 위해...

# 상관계수 R^2 출력
r2 = r2_score(Y_test_true, Y_pred)   # r2_score 함수를 이용해 결정계수 R^2을 구함
print(f"테스트 데이터 결정계수 (R²): {r2:.4f}")  # r2를 소수점 뒤에 4자리까지만 출력


# best_epoch 출력 + 최소 val_loss 출력
best_epoch = np.argmin(history.history['val_loss']) + 1  # 가장 val_loss 가 낮았던 epoch 수를 찾기 // np.argmin 함수는 리스트에서 가장 작은 값의 인덱스(위치) 출력
print(f"최적의 epoch: {best_epoch}")                      # 위에 것을 이어 쓰자면 model.fit.history이다. 뒤의 .history를 통해 모든 훈련과정의 기록(log)를 출력 // 그 중 val_loss 만 뽑아서 보기 -- 그 중 가장 작은 값의 인덱스 출력 np.argmin
print(f"최소 val_loss: {history.history['val_loss'][best_epoch-1]:.5f}") # .history에서 np.argmin까지 하면 index 번호에 자동으로 +1을 해서 인간이 보기 편하도록 출력을 해줌 --- -1 해줘서 index 번호 넣어주기








# 5. 학습 과정 시각화 (Loss, MAE, R²)
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(21, 5))   # plt.subplots(1, 3) = 1행 3열로 전체 그래프 부분 나누기  // figsize는 전체 그래프 크기 // 전체 그래프 구간을 나눠서 각각 할당해서 그릴 때 subplot 이용

# ax1 = 첫번쨰 그림판 --  Loss 그래프 그리기
ax1.plot(history.history['loss'], label='Training Loss')   # 참고로 history = model.fit() 이라고 앞에서 정의를 해놓음 // 범례(legend)를 Training loss 라 이름지음
ax1.plot(history.history['val_loss'], label='Validation Loss')  # model.fit이 진행될때마다 loss 와 val_loss를 그리기
ax1.set_title('Loss (MSE)')  # set_title = 그래프 제목
ax1.set_xlabel('Epoch'); ax1.set_ylabel('Loss'); ax1.legend(); ax1.grid(True) # .legend() --- 아까 label로 이름 붙여놓은 애들 표시 // .grid(True) -- 격자무늬 추가


# ax2 = MAE
ax2.plot(history.history['mean_absolute_error'], label='Training MAE')   # 아까 model.compile 할 떄 MAE 미리 선언함
ax2.plot(history.history['val_mean_absolute_error'], label='Validation MAE')  # Keras는 자동으로 validation set의 키 값 앞에 접두사 val_을 붙여준다
ax2.set_title('Mean Absolute Error (MAE)')
ax2.set_xlabel('Epoch'); ax2.set_ylabel('MAE'); ax2.legend(); ax2.grid(True)

# ax3 = R² 수기계산(별도 그래프)
ax3.plot([r2]*len(history.history['loss']), label=f'Test R² = {r2:.3f}') # r2를 총 epoch 수만큼 만듦 -- 그래프 직선형으로 그리려고
ax3.set_title('Test R-squared')
ax3.set_xlabel('Epoch'); ax3.set_ylabel('R²'); ax3.legend(); ax3.grid(True)
ax3.set_ylim(bottom=0, top=1)

plt.tight_layout() # layout 자동으로 깔끔하게 그래프 보여줌
plt.show()  # 화면에 그래프 출력









# 6. 실제값-예측값 산점도
plt.figure(figsize=(7,7))
plt.scatter(Y_test_true, Y_pred, alpha=0.5) # alpha는 투명도를 의미 .scatter()을 통해 산점도 그리기 . x 값은 실제값 y 값은 예측값

# y = x 기준선 그리기
plt.plot([Y_test_true.min(), Y_test_true.max()],  # 선의 시작과 끝점 x좌표 
         [Y_test_true.min(), Y_test_true.max()], 'r--', lw=2, label='Perfect') # 선의 시작과 끝점 y좌표 --- x좌표와 같으므로 y = x 그래프를 그린다  # lw = linewidth = 선 굵기
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title(f"Actual vs. Predicted (R² = {r2:.3f})")
plt.legend(); plt.grid(True); plt.axis('equal') #plt.axis('equal')을 통해 y=x에 
plt.show()



# 7. 잔차 플롯 (residuals)
residuals = (Y_test_true.flatten() - Y_pred.flatten())   # residuals = 실제값 - 예측값
plt.figure(figsize=(8,6))    # 그래프 크기
plt.scatter(Y_pred, residuals, alpha=0.6)  # x축 값 = 예측값, y축 값 = (실제값- 예측값)
plt.axhline(0, color='red', linestyle='--') # axhline = 수평선(Axis Horizontal Line)**을 그리는 함수
plt.xlabel('Predicted Values')
plt.ylabel('Residuals (Actual - Predicted)')
plt.title('Residual Plot')
plt.grid(True) # 뒤에 격자 표시
plt.show()



# 모델 성능 요약 
print(f"\n=== 최종 모델 성능 요약 ===")
print(f"모델 구조: 8-{optimal_units1}-{optimal_units2}-1")
print(f"활성화 함수: {optimal_activation}")
print(f"최적 epoch: {best_epoch}")
print(f"테스트 R²: {r2:.4f}")
print(f"테스트 MAE: {test_mae:.4f}")
# Out:
# --- 모델 학습을 시작합니다 ---
# Epoch 1/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0240 - mean_absolute_error: 0.1167 - val_loss: 0.0084 - val_mean_absolute_error: 0.0589
# Epoch 2/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0077 - mean_absolute_error: 0.0562 - val_loss: 0.0062 - val_mean_absolute_error: 0.0481
# Epoch 3/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053 - mean_absolute_error: 0.0462 - val_loss: 0.0053 - val_mean_absolute_error: 0.0412
# Epoch 4/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0051 - mean_absolute_error: 0.0443 - val_loss: 0.0048 - val_mean_absolute_error: 0.0383
# Epoch 5/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - mean_absolute_error: 0.0362 - val_loss: 0.0044 - val_mean_absolute_error: 0.0391
# Epoch 6/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mean_absolute_error: 0.0365 - val_loss: 0.0039 - val_mean_absolute_error: 0.0342
# Epoch 7/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0310 - val_loss: 0.0037 - val_mean_absolute_error: 0.0364
# Epoch 8/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mean_absolute_error: 0.0344 - val_loss: 0.0035 - val_mean_absolute_error: 0.0310
# Epoch 9/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mean_absolute_error: 0.0283 - val_loss: 0.0032 - val_mean_absolute_error: 0.0308
# Epoch 10/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0027 - mean_absolute_error: 0.0303 - val_loss: 0.0029 - val_mean_absolute_error: 0.0313
# Epoch 11/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035 - mean_absolute_error: 0.0327 - val_loss: 0.0027 - val_mean_absolute_error: 0.0274
# Epoch 12/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mean_absolute_error: 0.0263 - val_loss: 0.0026 - val_mean_absolute_error: 0.0272
# Epoch 13/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mean_absolute_error: 0.0253 - val_loss: 0.0026 - val_mean_absolute_error: 0.0270
# Epoch 14/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029 - mean_absolute_error: 0.0277 - val_loss: 0.0024 - val_mean_absolute_error: 0.0258
# Epoch 15/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mean_absolute_error: 0.0251 - val_loss: 0.0023 - val_mean_absolute_error: 0.0246
# Epoch 16/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0247 - val_loss: 0.0022 - val_mean_absolute_error: 0.0250
# Epoch 17/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mean_absolute_error: 0.0242 - val_loss: 0.0021 - val_mean_absolute_error: 0.0240
# Epoch 18/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mean_absolute_error: 0.0230 - val_loss: 0.0020 - val_mean_absolute_error: 0.0250
# Epoch 19/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - mean_absolute_error: 0.0220 - val_loss: 0.0020 - val_mean_absolute_error: 0.0233
# Epoch 20/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0229 - val_loss: 0.0019 - val_mean_absolute_error: 0.0215
# Epoch 21/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0207 - val_loss: 0.0018 - val_mean_absolute_error: 0.0208
# Epoch 22/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mean_absolute_error: 0.0199 - val_loss: 0.0017 - val_mean_absolute_error: 0.0229
# Epoch 23/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0222 - val_loss: 0.0016 - val_mean_absolute_error: 0.0208
# Epoch 24/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0197 - val_loss: 0.0016 - val_mean_absolute_error: 0.0222
# Epoch 25/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0198 - val_loss: 0.0015 - val_mean_absolute_error: 0.0200
# Epoch 26/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0182 - val_loss: 0.0015 - val_mean_absolute_error: 0.0208
# Epoch 27/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mean_absolute_error: 0.0202 - val_loss: 0.0016 - val_mean_absolute_error: 0.0228
# Epoch 28/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0187 - val_loss: 0.0016 - val_mean_absolute_error: 0.0185
# Epoch 29/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8827e-04 - mean_absolute_error: 0.0170 - val_loss: 0.0014 - val_mean_absolute_error: 0.0236
# Epoch 30/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0012 - mean_absolute_error: 0.0188 - val_loss: 0.0013 - val_mean_absolute_error: 0.0179
# Epoch 31/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0171 - val_loss: 0.0013 - val_mean_absolute_error: 0.0167
# Epoch 32/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0181 - val_loss: 0.0012 - val_mean_absolute_error: 0.0191
# Epoch 33/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4222e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0012 - val_mean_absolute_error: 0.0183
# Epoch 34/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5922e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0011 - val_mean_absolute_error: 0.0166
# Epoch 35/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7353e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0010 - val_mean_absolute_error: 0.0172
# Epoch 36/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6018e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0010 - val_mean_absolute_error: 0.0171
# Epoch 37/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6716e-04 - mean_absolute_error: 0.0147 - val_loss: 9.8301e-04 - val_mean_absolute_error: 0.0172
# Epoch 38/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5902e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0010 - val_mean_absolute_error: 0.0152
# Epoch 39/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2227e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0014 - val_mean_absolute_error: 0.0164
# Epoch 40/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2415e-04 - mean_absolute_error: 0.0148 - val_loss: 9.0738e-04 - val_mean_absolute_error: 0.0146
# Epoch 41/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1962e-04 - mean_absolute_error: 0.0125 - val_loss: 9.1414e-04 - val_mean_absolute_error: 0.0172
# Epoch 42/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3176e-04 - mean_absolute_error: 0.0154 - val_loss: 9.4901e-04 - val_mean_absolute_error: 0.0143
# Epoch 43/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7182e-04 - mean_absolute_error: 0.0146 - val_loss: 8.1677e-04 - val_mean_absolute_error: 0.0140
# Epoch 44/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0548e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0011 - val_mean_absolute_error: 0.0147
# Epoch 45/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1828e-04 - mean_absolute_error: 0.0133 - val_loss: 7.2525e-04 - val_mean_absolute_error: 0.0145
# Epoch 46/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2210e-04 - mean_absolute_error: 0.0134 - val_loss: 7.0561e-04 - val_mean_absolute_error: 0.0139
# Epoch 47/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3172e-04 - mean_absolute_error: 0.0131 - val_loss: 7.2507e-04 - val_mean_absolute_error: 0.0158
# Epoch 48/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3706e-04 - mean_absolute_error: 0.0129 - val_loss: 6.5327e-04 - val_mean_absolute_error: 0.0132
# Epoch 49/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2273e-04 - mean_absolute_error: 0.0135 - val_loss: 6.5939e-04 - val_mean_absolute_error: 0.0131
# Epoch 50/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6293e-04 - mean_absolute_error: 0.0138 - val_loss: 7.1730e-04 - val_mean_absolute_error: 0.0127
# Epoch 51/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1448e-04 - mean_absolute_error: 0.0119 - val_loss: 7.5790e-04 - val_mean_absolute_error: 0.0148
# Epoch 52/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4966e-04 - mean_absolute_error: 0.0133 - val_loss: 6.2583e-04 - val_mean_absolute_error: 0.0141
# Epoch 53/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5925e-04 - mean_absolute_error: 0.0150 - val_loss: 7.7636e-04 - val_mean_absolute_error: 0.0127
# Epoch 54/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0215e-04 - mean_absolute_error: 0.0119 - val_loss: 6.8488e-04 - val_mean_absolute_error: 0.0136
# Epoch 55/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3300e-04 - mean_absolute_error: 0.0138 - val_loss: 5.9243e-04 - val_mean_absolute_error: 0.0131
# Epoch 56/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6781e-04 - mean_absolute_error: 0.0119 - val_loss: 5.7740e-04 - val_mean_absolute_error: 0.0117
# Epoch 57/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2368e-04 - mean_absolute_error: 0.0115 - val_loss: 5.3490e-04 - val_mean_absolute_error: 0.0121
# Epoch 58/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4838e-04 - mean_absolute_error: 0.0116 - val_loss: 6.2135e-04 - val_mean_absolute_error: 0.0134
# Epoch 59/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4836e-04 - mean_absolute_error: 0.0119 - val_loss: 6.0402e-04 - val_mean_absolute_error: 0.0123
# Epoch 60/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0964e-04 - mean_absolute_error: 0.0112 - val_loss: 4.9931e-04 - val_mean_absolute_error: 0.0118
# Epoch 61/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9811e-04 - mean_absolute_error: 0.0108 - val_loss: 5.2163e-04 - val_mean_absolute_error: 0.0123
# Epoch 62/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2771e-04 - mean_absolute_error: 0.0122 - val_loss: 6.5492e-04 - val_mean_absolute_error: 0.0125
# Epoch 63/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8752e-04 - mean_absolute_error: 0.0136 - val_loss: 7.9875e-04 - val_mean_absolute_error: 0.0126
# Epoch 64/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9612e-04 - mean_absolute_error: 0.0109 - val_loss: 4.7541e-04 - val_mean_absolute_error: 0.0122
# Epoch 65/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4278e-04 - mean_absolute_error: 0.0104 - val_loss: 4.8877e-04 - val_mean_absolute_error: 0.0124
# Epoch 66/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1588e-04 - mean_absolute_error: 0.0115 - val_loss: 6.1029e-04 - val_mean_absolute_error: 0.0136
# Epoch 67/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1442e-04 - mean_absolute_error: 0.0109 - val_loss: 6.6743e-04 - val_mean_absolute_error: 0.0138
# Epoch 68/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3558e-04 - mean_absolute_error: 0.0100 - val_loss: 5.4535e-04 - val_mean_absolute_error: 0.0109
# Epoch 69/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8318e-04 - mean_absolute_error: 0.0096 - val_loss: 4.1967e-04 - val_mean_absolute_error: 0.0106
# Epoch 70/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9304e-04 - mean_absolute_error: 0.0111 - val_loss: 4.4526e-04 - val_mean_absolute_error: 0.0117
# Epoch 71/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6776e-04 - mean_absolute_error: 0.0103 - val_loss: 4.1064e-04 - val_mean_absolute_error: 0.0104
# Epoch 72/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7752e-04 - mean_absolute_error: 0.0100 - val_loss: 4.0934e-04 - val_mean_absolute_error: 0.0106
# Epoch 73/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2843e-04 - mean_absolute_error: 0.0096 - val_loss: 6.0466e-04 - val_mean_absolute_error: 0.0111
# Epoch 74/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7013e-04 - mean_absolute_error: 0.0100 - val_loss: 4.0428e-04 - val_mean_absolute_error: 0.0110
# Epoch 75/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8937e-04 - mean_absolute_error: 0.0095 - val_loss: 4.5882e-04 - val_mean_absolute_error: 0.0110
# Epoch 76/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1031e-04 - mean_absolute_error: 0.0097 - val_loss: 3.9910e-04 - val_mean_absolute_error: 0.0103
# Epoch 77/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5404e-04 - mean_absolute_error: 0.0100 - val_loss: 4.0055e-04 - val_mean_absolute_error: 0.0104
# Epoch 78/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9625e-04 - mean_absolute_error: 0.0092 - val_loss: 3.7455e-04 - val_mean_absolute_error: 0.0102
# Epoch 79/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3240e-04 - mean_absolute_error: 0.0083 - val_loss: 3.6649e-04 - val_mean_absolute_error: 0.0100
# Epoch 80/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5261e-04 - mean_absolute_error: 0.0088 - val_loss: 5.7153e-04 - val_mean_absolute_error: 0.0118
# Epoch 81/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6911e-04 - mean_absolute_error: 0.0093 - val_loss: 3.4569e-04 - val_mean_absolute_error: 0.0096
# Epoch 82/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9069e-04 - mean_absolute_error: 0.0097 - val_loss: 3.8752e-04 - val_mean_absolute_error: 0.0116
# Epoch 83/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2402e-04 - mean_absolute_error: 0.0094 - val_loss: 3.8816e-04 - val_mean_absolute_error: 0.0101
# Epoch 84/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3274e-04 - mean_absolute_error: 0.0128 - val_loss: 3.4949e-04 - val_mean_absolute_error: 0.0099
# Epoch 85/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6330e-04 - mean_absolute_error: 0.0091 - val_loss: 3.7741e-04 - val_mean_absolute_error: 0.0103
# Epoch 86/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6944e-04 - mean_absolute_error: 0.0127 - val_loss: 3.7641e-04 - val_mean_absolute_error: 0.0104
# Epoch 87/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9800e-04 - mean_absolute_error: 0.0109 - val_loss: 3.3541e-04 - val_mean_absolute_error: 0.0094
# Epoch 88/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4413e-04 - mean_absolute_error: 0.0085 - val_loss: 4.2457e-04 - val_mean_absolute_error: 0.0100
# Epoch 89/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6565e-04 - mean_absolute_error: 0.0091 - val_loss: 4.5622e-04 - val_mean_absolute_error: 0.0106
# Epoch 90/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8982e-04 - mean_absolute_error: 0.0102 - val_loss: 3.7806e-04 - val_mean_absolute_error: 0.0101
# Epoch 91/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5080e-04 - mean_absolute_error: 0.0085 - val_loss: 3.4830e-04 - val_mean_absolute_error: 0.0103
# Epoch 92/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7187e-04 - mean_absolute_error: 0.0078 - val_loss: 3.4471e-04 - val_mean_absolute_error: 0.0095
# Epoch 93/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2240e-04 - mean_absolute_error: 0.0088 - val_loss: 3.1798e-04 - val_mean_absolute_error: 0.0095
# Epoch 94/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5174e-04 - mean_absolute_error: 0.0085 - val_loss: 3.0805e-04 - val_mean_absolute_error: 0.0092
# Epoch 95/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1406e-04 - mean_absolute_error: 0.0085 - val_loss: 3.4987e-04 - val_mean_absolute_error: 0.0092
# Epoch 96/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2764e-04 - mean_absolute_error: 0.0097 - val_loss: 3.2303e-04 - val_mean_absolute_error: 0.0094
# Epoch 97/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4873e-04 - mean_absolute_error: 0.0086 - val_loss: 3.1870e-04 - val_mean_absolute_error: 0.0093
# Epoch 98/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4737e-04 - mean_absolute_error: 0.0086 - val_loss: 3.0662e-04 - val_mean_absolute_error: 0.0097
# Epoch 99/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2053e-04 - mean_absolute_error: 0.0085 - val_loss: 2.8731e-04 - val_mean_absolute_error: 0.0088
# Epoch 100/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1726e-04 - mean_absolute_error: 0.0091 - val_loss: 8.2599e-04 - val_mean_absolute_error: 0.0128
# Epoch 101/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1658e-04 - mean_absolute_error: 0.0100 - val_loss: 2.7685e-04 - val_mean_absolute_error: 0.0091
# Epoch 102/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1893e-04 - mean_absolute_error: 0.0080 - val_loss: 2.6217e-04 - val_mean_absolute_error: 0.0084
# Epoch 103/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2659e-04 - mean_absolute_error: 0.0086 - val_loss: 4.3199e-04 - val_mean_absolute_error: 0.0103
# Epoch 104/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1471e-04 - mean_absolute_error: 0.0085 - val_loss: 3.3177e-04 - val_mean_absolute_error: 0.0097
# Epoch 105/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6666e-04 - mean_absolute_error: 0.0102 - val_loss: 2.9481e-04 - val_mean_absolute_error: 0.0089
# Epoch 106/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7523e-04 - mean_absolute_error: 0.0095 - val_loss: 3.9397e-04 - val_mean_absolute_error: 0.0102
# Epoch 107/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6328e-04 - mean_absolute_error: 0.0105 - val_loss: 2.7810e-04 - val_mean_absolute_error: 0.0085
# Epoch 108/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4909e-04 - mean_absolute_error: 0.0068 - val_loss: 3.3205e-04 - val_mean_absolute_error: 0.0094
# Epoch 109/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7617e-04 - mean_absolute_error: 0.0070 - val_loss: 5.0520e-04 - val_mean_absolute_error: 0.0121
# Epoch 110/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2747e-04 - mean_absolute_error: 0.0084 - val_loss: 2.8583e-04 - val_mean_absolute_error: 0.0094
# Epoch 111/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7323e-04 - mean_absolute_error: 0.0076 - val_loss: 3.4045e-04 - val_mean_absolute_error: 0.0085
# Epoch 112/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5904e-04 - mean_absolute_error: 0.0087 - val_loss: 3.1823e-04 - val_mean_absolute_error: 0.0090
# Epoch 113/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6517e-04 - mean_absolute_error: 0.0086 - val_loss: 2.8771e-04 - val_mean_absolute_error: 0.0093
# Epoch 114/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0001e-04 - mean_absolute_error: 0.0077 - val_loss: 3.3810e-04 - val_mean_absolute_error: 0.0086
# Epoch 115/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6362e-04 - mean_absolute_error: 0.0083 - val_loss: 2.2501e-04 - val_mean_absolute_error: 0.0077
# Epoch 116/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6245e-04 - mean_absolute_error: 0.0074 - val_loss: 2.4639e-04 - val_mean_absolute_error: 0.0084
# Epoch 117/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2070e-04 - mean_absolute_error: 0.0096 - val_loss: 4.5060e-04 - val_mean_absolute_error: 0.0096
# Epoch 118/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8644e-04 - mean_absolute_error: 0.0085 - val_loss: 2.5438e-04 - val_mean_absolute_error: 0.0082
# Epoch 119/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8284e-04 - mean_absolute_error: 0.0074 - val_loss: 3.4037e-04 - val_mean_absolute_error: 0.0096
# Epoch 120/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4182e-04 - mean_absolute_error: 0.0084 - val_loss: 2.2740e-04 - val_mean_absolute_error: 0.0083
# Epoch 121/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5377e-04 - mean_absolute_error: 0.0075 - val_loss: 2.4572e-04 - val_mean_absolute_error: 0.0079
# Epoch 122/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1214e-04 - mean_absolute_error: 0.0079 - val_loss: 2.6339e-04 - val_mean_absolute_error: 0.0080
# Epoch 123/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5744e-04 - mean_absolute_error: 0.0072 - val_loss: 3.8048e-04 - val_mean_absolute_error: 0.0091
# Epoch 124/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1170e-04 - mean_absolute_error: 0.0082 - val_loss: 2.7955e-04 - val_mean_absolute_error: 0.0084
# Epoch 125/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5124e-04 - mean_absolute_error: 0.0069 - val_loss: 2.2362e-04 - val_mean_absolute_error: 0.0078
# Epoch 126/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9433e-04 - mean_absolute_error: 0.0077 - val_loss: 2.5941e-04 - val_mean_absolute_error: 0.0091
# Epoch 127/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2669e-04 - mean_absolute_error: 0.0085 - val_loss: 2.7092e-04 - val_mean_absolute_error: 0.0080
# Epoch 128/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5098e-04 - mean_absolute_error: 0.0074 - val_loss: 3.2153e-04 - val_mean_absolute_error: 0.0087
# Epoch 129/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5797e-04 - mean_absolute_error: 0.0073 - val_loss: 2.6064e-04 - val_mean_absolute_error: 0.0090
# Epoch 130/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1534e-04 - mean_absolute_error: 0.0066 - val_loss: 2.0712e-04 - val_mean_absolute_error: 0.0081
# Epoch 131/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0055e-04 - mean_absolute_error: 0.0078 - val_loss: 2.5155e-04 - val_mean_absolute_error: 0.0099
# Epoch 132/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3212e-04 - mean_absolute_error: 0.0070 - val_loss: 2.6397e-04 - val_mean_absolute_error: 0.0092
# Epoch 133/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0149e-04 - mean_absolute_error: 0.0081 - val_loss: 3.1344e-04 - val_mean_absolute_error: 0.0093
# Epoch 134/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4332e-04 - mean_absolute_error: 0.0067 - val_loss: 1.9503e-04 - val_mean_absolute_error: 0.0078
# Epoch 135/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4605e-04 - mean_absolute_error: 0.0070 - val_loss: 1.8031e-04 - val_mean_absolute_error: 0.0076
# Epoch 136/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0251e-04 - mean_absolute_error: 0.0063 - val_loss: 2.1104e-04 - val_mean_absolute_error: 0.0083
# Epoch 137/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4831e-04 - mean_absolute_error: 0.0073 - val_loss: 3.0532e-04 - val_mean_absolute_error: 0.0100
# Epoch 138/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1933e-04 - mean_absolute_error: 0.0085 - val_loss: 2.6462e-04 - val_mean_absolute_error: 0.0087
# Epoch 139/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9593e-04 - mean_absolute_error: 0.0086 - val_loss: 2.0107e-04 - val_mean_absolute_error: 0.0075
# Epoch 140/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3845e-04 - mean_absolute_error: 0.0067 - val_loss: 2.8030e-04 - val_mean_absolute_error: 0.0090
# Epoch 141/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7176e-04 - mean_absolute_error: 0.0089 - val_loss: 2.7935e-04 - val_mean_absolute_error: 0.0085
# Epoch 142/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5231e-04 - mean_absolute_error: 0.0071 - val_loss: 2.2541e-04 - val_mean_absolute_error: 0.0081
# Epoch 143/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2334e-04 - mean_absolute_error: 0.0067 - val_loss: 1.9406e-04 - val_mean_absolute_error: 0.0084
# Epoch 144/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0075e-04 - mean_absolute_error: 0.0061 - val_loss: 1.8677e-04 - val_mean_absolute_error: 0.0072
# Epoch 145/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3778e-04 - mean_absolute_error: 0.0065 - val_loss: 2.1865e-04 - val_mean_absolute_error: 0.0072
# Epoch 146/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7480e-04 - mean_absolute_error: 0.0071 - val_loss: 1.8791e-04 - val_mean_absolute_error: 0.0074
# Epoch 147/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1252e-04 - mean_absolute_error: 0.0061 - val_loss: 1.8020e-04 - val_mean_absolute_error: 0.0079
# Epoch 148/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8248e-04 - mean_absolute_error: 0.0081 - val_loss: 2.5291e-04 - val_mean_absolute_error: 0.0082
# Epoch 149/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6691e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8906e-04 - val_mean_absolute_error: 0.0073
# Epoch 150/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9425e-04 - mean_absolute_error: 0.0076 - val_loss: 2.7100e-04 - val_mean_absolute_error: 0.0111
# Epoch 151/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6636e-04 - mean_absolute_error: 0.0076 - val_loss: 1.9729e-04 - val_mean_absolute_error: 0.0083
# Epoch 152/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3478e-04 - mean_absolute_error: 0.0069 - val_loss: 1.7606e-04 - val_mean_absolute_error: 0.0073
# Epoch 153/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2611e-04 - mean_absolute_error: 0.0083 - val_loss: 1.8534e-04 - val_mean_absolute_error: 0.0080
# Epoch 154/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1194e-04 - mean_absolute_error: 0.0068 - val_loss: 4.9029e-04 - val_mean_absolute_error: 0.0096
# Epoch 155/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4881e-04 - mean_absolute_error: 0.0109 - val_loss: 3.2490e-04 - val_mean_absolute_error: 0.0087
# Epoch 156/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8948e-04 - mean_absolute_error: 0.0074 - val_loss: 1.9194e-04 - val_mean_absolute_error: 0.0068
# Epoch 157/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2924e-04 - mean_absolute_error: 0.0064 - val_loss: 1.9057e-04 - val_mean_absolute_error: 0.0071
# Epoch 158/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0406e-04 - mean_absolute_error: 0.0059 - val_loss: 1.7475e-04 - val_mean_absolute_error: 0.0080
# Epoch 159/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3294e-04 - mean_absolute_error: 0.0072 - val_loss: 1.6680e-04 - val_mean_absolute_error: 0.0071
# Epoch 160/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2613e-04 - mean_absolute_error: 0.0065 - val_loss: 1.4390e-04 - val_mean_absolute_error: 0.0065
# Epoch 161/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1210e-04 - mean_absolute_error: 0.0063 - val_loss: 1.3037e-04 - val_mean_absolute_error: 0.0063
# Epoch 162/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5508e-04 - mean_absolute_error: 0.0072 - val_loss: 1.6760e-04 - val_mean_absolute_error: 0.0070
# Epoch 163/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0694e-04 - mean_absolute_error: 0.0061 - val_loss: 1.9689e-04 - val_mean_absolute_error: 0.0072
# Epoch 164/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6685e-04 - mean_absolute_error: 0.0076 - val_loss: 2.2942e-04 - val_mean_absolute_error: 0.0085
# Epoch 165/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9651e-04 - mean_absolute_error: 0.0080 - val_loss: 1.6617e-04 - val_mean_absolute_error: 0.0071
# Epoch 166/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1767e-04 - mean_absolute_error: 0.0068 - val_loss: 1.5032e-04 - val_mean_absolute_error: 0.0073
# Epoch 167/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2258e-05 - mean_absolute_error: 0.0059 - val_loss: 2.6156e-04 - val_mean_absolute_error: 0.0071
# Epoch 168/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1236e-04 - mean_absolute_error: 0.0060 - val_loss: 1.4667e-04 - val_mean_absolute_error: 0.0064
# Epoch 169/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2111e-05 - mean_absolute_error: 0.0054 - val_loss: 1.5544e-04 - val_mean_absolute_error: 0.0075
# Epoch 170/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1917e-04 - mean_absolute_error: 0.0073 - val_loss: 1.8104e-04 - val_mean_absolute_error: 0.0069
# Epoch 171/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4697e-05 - mean_absolute_error: 0.0056 - val_loss: 1.9633e-04 - val_mean_absolute_error: 0.0083
# Epoch 172/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1653e-04 - mean_absolute_error: 0.0081 - val_loss: 1.7044e-04 - val_mean_absolute_error: 0.0080
# Epoch 173/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1740e-04 - mean_absolute_error: 0.0067 - val_loss: 1.4521e-04 - val_mean_absolute_error: 0.0066
# Epoch 174/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4859e-05 - mean_absolute_error: 0.0055 - val_loss: 1.5497e-04 - val_mean_absolute_error: 0.0074
# Epoch 175/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8803e-05 - mean_absolute_error: 0.0060 - val_loss: 1.2101e-04 - val_mean_absolute_error: 0.0061
# Epoch 176/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3528e-05 - mean_absolute_error: 0.0059 - val_loss: 1.3674e-04 - val_mean_absolute_error: 0.0062
# Epoch 177/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2405e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2543e-04 - val_mean_absolute_error: 0.0069
# Epoch 178/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.2411e-05 - mean_absolute_error: 0.0056 - val_loss: 1.5569e-04 - val_mean_absolute_error: 0.0074
# Epoch 179/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3137e-05 - mean_absolute_error: 0.0060 - val_loss: 1.5411e-04 - val_mean_absolute_error: 0.0073
# Epoch 180/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5562e-05 - mean_absolute_error: 0.0059 - val_loss: 2.9567e-04 - val_mean_absolute_error: 0.0084
# Epoch 181/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9313e-04 - mean_absolute_error: 0.0078 - val_loss: 1.6172e-04 - val_mean_absolute_error: 0.0068
# Epoch 182/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8257e-05 - mean_absolute_error: 0.0055 - val_loss: 1.5811e-04 - val_mean_absolute_error: 0.0073
# Epoch 183/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5889e-05 - mean_absolute_error: 0.0059 - val_loss: 1.6771e-04 - val_mean_absolute_error: 0.0076
# Epoch 184/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4469e-04 - mean_absolute_error: 0.0069 - val_loss: 1.6209e-04 - val_mean_absolute_error: 0.0069
# Epoch 185/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6790e-04 - mean_absolute_error: 0.0076 - val_loss: 1.1220e-04 - val_mean_absolute_error: 0.0059
# Epoch 186/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5627e-05 - mean_absolute_error: 0.0058 - val_loss: 1.5738e-04 - val_mean_absolute_error: 0.0067
# Epoch 187/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0859e-04 - mean_absolute_error: 0.0065 - val_loss: 1.4307e-04 - val_mean_absolute_error: 0.0070
# Epoch 188/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.9319e-05 - mean_absolute_error: 0.0061 - val_loss: 1.4059e-04 - val_mean_absolute_error: 0.0087
# Epoch 189/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9269e-05 - mean_absolute_error: 0.0064 - val_loss: 1.3135e-04 - val_mean_absolute_error: 0.0069
# Epoch 190/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8611e-05 - mean_absolute_error: 0.0058 - val_loss: 1.4303e-04 - val_mean_absolute_error: 0.0068
# Epoch 191/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3397e-04 - mean_absolute_error: 0.0071 - val_loss: 1.4603e-04 - val_mean_absolute_error: 0.0065
# Epoch 192/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7959e-05 - mean_absolute_error: 0.0057 - val_loss: 2.2625e-04 - val_mean_absolute_error: 0.0078
# Epoch 193/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.9546e-05 - mean_absolute_error: 0.0060 - val_loss: 2.0189e-04 - val_mean_absolute_error: 0.0079
# Epoch 194/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5069e-05 - mean_absolute_error: 0.0060 - val_loss: 1.3933e-04 - val_mean_absolute_error: 0.0064
# Epoch 195/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1019e-05 - mean_absolute_error: 0.0057 - val_loss: 1.7596e-04 - val_mean_absolute_error: 0.0075
# Epoch 196/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6853e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2758e-04 - val_mean_absolute_error: 0.0072
# Epoch 197/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0011e-04 - mean_absolute_error: 0.0061 - val_loss: 2.2802e-04 - val_mean_absolute_error: 0.0079
# Epoch 198/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0970e-04 - mean_absolute_error: 0.0067 - val_loss: 1.1387e-04 - val_mean_absolute_error: 0.0061
# Epoch 199/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9811e-05 - mean_absolute_error: 0.0054 - val_loss: 2.4475e-04 - val_mean_absolute_error: 0.0075
# Epoch 200/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2645e-04 - mean_absolute_error: 0.0064 - val_loss: 1.4113e-04 - val_mean_absolute_error: 0.0068
# Epoch 201/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6046e-05 - mean_absolute_error: 0.0058 - val_loss: 1.1204e-04 - val_mean_absolute_error: 0.0060
# Epoch 202/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8731e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0011 - val_mean_absolute_error: 0.0117
# Epoch 203/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9265e-04 - mean_absolute_error: 0.0124 - val_loss: 2.0615e-04 - val_mean_absolute_error: 0.0078
# Epoch 204/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1178e-04 - mean_absolute_error: 0.0068 - val_loss: 1.1780e-04 - val_mean_absolute_error: 0.0067
# Epoch 205/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4027e-05 - mean_absolute_error: 0.0052 - val_loss: 1.5151e-04 - val_mean_absolute_error: 0.0064
# Epoch 206/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0310e-04 - mean_absolute_error: 0.0066 - val_loss: 1.6320e-04 - val_mean_absolute_error: 0.0084
# Epoch 207/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8844e-05 - mean_absolute_error: 0.0060 - val_loss: 1.1300e-04 - val_mean_absolute_error: 0.0064
# Epoch 208/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4270e-05 - mean_absolute_error: 0.0056 - val_loss: 1.0089e-04 - val_mean_absolute_error: 0.0065
# Epoch 209/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1805e-04 - mean_absolute_error: 0.0067 - val_loss: 1.7022e-04 - val_mean_absolute_error: 0.0082
# Epoch 210/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.1091e-05 - mean_absolute_error: 0.0058 - val_loss: 9.6468e-05 - val_mean_absolute_error: 0.0056
# Epoch 211/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5326e-05 - mean_absolute_error: 0.0051 - val_loss: 1.3494e-04 - val_mean_absolute_error: 0.0078
# Epoch 212/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.4781e-05 - mean_absolute_error: 0.0057 - val_loss: 1.1054e-04 - val_mean_absolute_error: 0.0058
# Epoch 213/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1075e-04 - mean_absolute_error: 0.0062 - val_loss: 1.1900e-04 - val_mean_absolute_error: 0.0066
# Epoch 214/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8904e-05 - mean_absolute_error: 0.0053 - val_loss: 1.1690e-04 - val_mean_absolute_error: 0.0060
# Epoch 215/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.4694e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2705e-04 - val_mean_absolute_error: 0.0063
# Epoch 216/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0711e-05 - mean_absolute_error: 0.0060 - val_loss: 1.0450e-04 - val_mean_absolute_error: 0.0059
# Epoch 217/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7715e-05 - mean_absolute_error: 0.0064 - val_loss: 1.7709e-04 - val_mean_absolute_error: 0.0067
# Epoch 218/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0811e-04 - mean_absolute_error: 0.0061 - val_loss: 9.3158e-05 - val_mean_absolute_error: 0.0055
# Epoch 219/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0772e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2370e-04 - val_mean_absolute_error: 0.0069
# Epoch 220/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5731e-05 - mean_absolute_error: 0.0055 - val_loss: 9.2157e-05 - val_mean_absolute_error: 0.0056
# Epoch 221/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6733e-05 - mean_absolute_error: 0.0054 - val_loss: 2.4765e-04 - val_mean_absolute_error: 0.0071
# Epoch 222/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9441e-04 - mean_absolute_error: 0.0078 - val_loss: 1.7201e-04 - val_mean_absolute_error: 0.0102
# Epoch 223/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1479e-04 - mean_absolute_error: 0.0066 - val_loss: 2.1885e-04 - val_mean_absolute_error: 0.0078
# Epoch 224/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0656e-05 - mean_absolute_error: 0.0059 - val_loss: 1.0976e-04 - val_mean_absolute_error: 0.0060
# Epoch 225/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4449e-05 - mean_absolute_error: 0.0057 - val_loss: 9.1531e-05 - val_mean_absolute_error: 0.0057
# Epoch 226/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9978e-05 - mean_absolute_error: 0.0051 - val_loss: 9.5289e-05 - val_mean_absolute_error: 0.0058
# Epoch 227/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2251e-05 - mean_absolute_error: 0.0049 - val_loss: 1.3317e-04 - val_mean_absolute_error: 0.0075
# Epoch 228/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9073e-05 - mean_absolute_error: 0.0050 - val_loss: 8.1303e-05 - val_mean_absolute_error: 0.0055
# Epoch 229/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6342e-05 - mean_absolute_error: 0.0054 - val_loss: 8.7240e-05 - val_mean_absolute_error: 0.0055
# Epoch 230/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8842e-05 - mean_absolute_error: 0.0053 - val_loss: 9.3735e-05 - val_mean_absolute_error: 0.0058
# Epoch 231/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3316e-05 - mean_absolute_error: 0.0048 - val_loss: 2.0949e-04 - val_mean_absolute_error: 0.0067
# Epoch 232/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5964e-04 - mean_absolute_error: 0.0093 - val_loss: 9.8574e-05 - val_mean_absolute_error: 0.0066
# Epoch 233/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2982e-05 - mean_absolute_error: 0.0059 - val_loss: 1.1567e-04 - val_mean_absolute_error: 0.0058
# Epoch 234/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9305e-05 - mean_absolute_error: 0.0060 - val_loss: 1.3815e-04 - val_mean_absolute_error: 0.0069
# Epoch 235/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6108e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1037e-04 - val_mean_absolute_error: 0.0060
# Epoch 236/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2616e-04 - mean_absolute_error: 0.0064 - val_loss: 1.4134e-04 - val_mean_absolute_error: 0.0063
# Epoch 237/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9581e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2490e-04 - val_mean_absolute_error: 0.0060
# Epoch 238/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0043e-05 - mean_absolute_error: 0.0052 - val_loss: 1.0396e-04 - val_mean_absolute_error: 0.0058
# Epoch 239/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7821e-05 - mean_absolute_error: 0.0047 - val_loss: 1.0437e-04 - val_mean_absolute_error: 0.0058
# Epoch 240/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7981e-05 - mean_absolute_error: 0.0054 - val_loss: 1.0806e-04 - val_mean_absolute_error: 0.0064
# Epoch 241/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5543e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3496e-04 - val_mean_absolute_error: 0.0065
# Epoch 242/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4438e-05 - mean_absolute_error: 0.0056 - val_loss: 8.7944e-05 - val_mean_absolute_error: 0.0060
# Epoch 243/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1992e-04 - mean_absolute_error: 0.0061 - val_loss: 1.0352e-04 - val_mean_absolute_error: 0.0070
# Epoch 244/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1505e-05 - mean_absolute_error: 0.0058 - val_loss: 9.1074e-05 - val_mean_absolute_error: 0.0057
# Epoch 245/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3363e-05 - mean_absolute_error: 0.0054 - val_loss: 9.6817e-05 - val_mean_absolute_error: 0.0063
# Epoch 246/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5965e-05 - mean_absolute_error: 0.0051 - val_loss: 1.1492e-04 - val_mean_absolute_error: 0.0067
# Epoch 247/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0386e-05 - mean_absolute_error: 0.0051 - val_loss: 9.5320e-05 - val_mean_absolute_error: 0.0058
# Epoch 248/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1305e-05 - mean_absolute_error: 0.0049 - val_loss: 1.0491e-04 - val_mean_absolute_error: 0.0061
#
# --- 모델 학습 완료 ---
#
# --- 테스트 데이터 이용 모델 성능 평가 ---
# 테스트 데이터 손실 (MSE): 0.0001
# 테스트 데이터 평균 절대 오차 (MAE): 0.0053
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 테스트 데이터 결정계수 (R²): 0.9908
# 최적의 epoch: 228
# 최소 val_loss: 0.00008
# === 최종 모델 성능 요약 ===
# 모델 구조: 8-32-16-1
# 활성화 함수: relu
# 최적 epoch: 228
# 테스트 R²: 0.9908
# 테스트 MAE: 0.0053
