# %%
import numpy as np
from scipy.interpolate import BSpline
import matplotlib.pyplot as plt

c = [0.07280717045068741, 0.06708534061908722, 0.0617905855178833, 0.05658593028783798, 0.05166981741786003, 0.04702967032790184, 0.042715348303318024, 0.038414716720581055, 0.03397442772984505, 0.029585441574454308, 0.02501518838107586, 0.020543387159705162, 0.015806473791599274, 0.011166684329509735, 0.006021266337484121, 0.00025579112116247416, -0.005959654226899147, -0.011883728206157684, -0.017452511936426163, -0.023428834974765778, -0.030336620286107063, -0.036911964416503906, -0.044032543897628784, -0.05093676224350929, -0.059248801320791245, -0.06725428998470306, -0.07617101818323135, -0.0848553329706192, -0.09339479357004166, -0.10139043629169464, -0.10909087210893631, -0.11760548502206802, -0.1264234483242035]
k = 3
# t = [-k+i for i in range(k-1)] + [i for i in range(len(c))] + [len(c) + i for i in range(k-1)]
t = [-1.1998, -1.1331, -1.0665, -0.9998, -0.9427, -0.8759, -0.7994, -0.7407,
         -0.6764, -0.6082, -0.5460, -0.4739, -0.4084, -0.3407, -0.2772, -0.2057,
         -0.1487, -0.0717,  0.0157,  0.0781,  0.1344,  0.2023,  0.2708,  0.3479,
          0.3969,  0.4741,  0.5383,  0.6179,  0.6795,  0.7598,  0.8271,  0.8792,
          0.9427,  0.9997,  1.0663,  1.1330,  1.1996]

spl = BSpline(t, c, k)

x = np.linspace(t[1], t[-2], 50)
y = spl(x)

plt.plot(x, y)
plt.scatter(t[k-1:-k+1], c, edgecolor='k', facecolor='none')
plt.grid(True)
plt.show()
