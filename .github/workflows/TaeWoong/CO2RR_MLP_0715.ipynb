# %% [markdown]
# MLP 이용 간단한 ANN을 만들어서 데이터석 진행 (KAN 비교용)

# %% [markdown]
# step1. Excel 데이터 가져오기

# %%
# 엑셀 데이터 로드 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import os
import numpy as np

# 엑셀 데이터 로드 
filepath = r"C:\Users\kepco201\Desktop\KAN_python\pykan-master\.github\workflows\TaeWoong\25.01.14_CO2RR_GSA.xlsx"
xls = pd.ExcelFile(filepath) 

# 엑셀 데이터 로드 후 즉시 수치형 데이터만 선별
df_input = pd.read_excel(xls, sheet_name='Input')
df_out = pd.read_excel(xls, sheet_name='Output')

# 데이터 타입 확인
print("=== 데이터 타입 확인 ===")
print("Input 데이터 타입:")
print(df_input.dtypes)
print(f"Input 데이터 형태: {df_input.shape}")

# ✅ 올바른 방법 1: 컬럼 이름으로 직접 선택
selected_columns = [
    "Current density (mA/cm2)", 
    "Faradaic efficiency (%)", 
    "CO coversion",
    "Voltage (V)", 
    "Electricity cost ($/kWh)", 
    "Membrain cost ($/m2)",
    "Catpure energy (GJ/ton)", 
    "Crossover rate"
]

# DataFrame에서 해당 컬럼들 선택
X = df_input[selected_columns].copy()



# Y 데이터 선택 (닫는 괄호 추가)
Y = df_out[['Required energy_total (MJ/kgCO)']].values.reshape(-1, 1)  # MSP ($/kgCO)  # Required energy_total (MJ/kgCO)

print(f"\n=== 최종 데이터 형태 ===")
print(f"X 형태: {X.shape}")
print(f"Y 형태: {Y.shape}")
print(f"X 컬럼: {X.columns.tolist()}")
# Out:
# === 데이터 타입 확인 ===
# Input 데이터 타입:
# Current density (mA/cm2)    float64
# Faradaic efficiency (%)     float64
# CO coversion                float64
# Voltage (V)                 float64
# Electricity cost ($/kWh)    float64
# Membrain cost ($/m2)        float64
# Catpure energy (GJ/ton)     float64
# Crossover rate              float64
# Unnamed: 8                  float64
# Unnamed: 9                   object
# Unnamed: 10                  object
# Unnamed: 11                  object
# Unnamed: 12                 float64
# Unnamed: 13                  object
# Unnamed: 14                 float64
# Unnamed: 15                  object
# Unnamed: 16                 float64
# Unnamed: 17                  object
# Unnamed: 18                 float64
# Unnamed: 19                 float64
# Unnamed: 20                  object
# dtype: object
# Input 데이터 형태: (2501, 21)
#
# === 최종 데이터 형태 ===
# X 형태: (2501, 8)
# Y 형태: (2501, 1)
# X 컬럼: ['Current density (mA/cm2)', 'Faradaic efficiency (%)', 'CO coversion', 'Voltage (V)', 'Electricity cost ($/kWh)', 'Membrain cost ($/m2)', 'Catpure energy (GJ/ton)', 'Crossover rate']

# %% [markdown]
# step2. 데이터 분리 및 스케일링 _ 여기서는 평균 0 표준편차 1로 스케일링함

# %%
# 1차 분할 (test 분리)
X_train_val, X_test, Y_train_val, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
# 2차 분할(train, valid 분리)
X_train, X_val, Y_train, Y_val = train_test_split(X_train_val, Y_train_val, test_size=0.2, random_state=42)

# train:valid:test = 64:16:20

# 데이터 스케일링(표준화)(평균, 표준편차 이용)

# **중요** : 스케일러는 반드시 *훈련 데이터(X_train)*에만 fit 해야한다. 그래야 valid나 test 데이터의 정보가 누출될 위험을 줄인다

scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)  # X_train 데이터를 이용해 scaler_X.transform을 학습 + X_train_scaled 반환
X_val_scaled = scaler_X.transform(X_val) # train 데이터로 학습한 scaler_X.transform 함수로 다른 것들도 학습
X_test_scaled = scaler_X.transform(X_test) 

scaler_Y = StandardScaler()
Y_train_scaled = scaler_Y.fit_transform(Y_train)  # Y_train 데이터를 이용해 scaler_Y.transform을 학습 + Y_train_scaled 반환
Y_val_scaled = scaler_Y.transform(Y_val)
Y_test_scaled = scaler_Y.transform(Y_test)

# 분리한 결과 어떻게 나오는지 확인해보기

print("\n--- 데이터 분할 및 전처리 최종 결과 ---")
print(f"훈련 데이터 형태: X({X_train_scaled.shape}), Y({Y_train_scaled.shape})")
print(f"검증 데이터 형태: X({X_val_scaled.shape}), Y({Y_val_scaled.shape})")
print(f"테스트 데이터 형태: X({X_test_scaled.shape}), Y({Y_test_scaled.shape})")

print("\n\n 스케일링된 훈련 데이터(X_train_scaled) 샘플:")
print(pd.DataFrame(X_train_scaled, columns=X_train.columns).head())  
# .head()는 첫번째 5줄만 출력 , numpy 배열은 컬럼명이 없어 데이터 구조가 한눈에 파악하기 어렵다. 
# 그래서 pd.DataFrame(..., columns=...)을 이용하면, 스케일링된 데이터를 원래 컬럼명과 함께 보기 좋게 pandas DataFrame으로 변환 이용
# Out:
# --- 데이터 분할 및 전처리 최종 결과 ---
# 훈련 데이터 형태: X((1600, 8)), Y((1600, 1))
# 검증 데이터 형태: X((400, 8)), Y((400, 1))
# 테스트 데이터 형태: X((501, 8)), Y((501, 1))
#
#
#  스케일링된 훈련 데이터(X_train_scaled) 샘플:
#    Current density (mA/cm2)  Faradaic efficiency (%)  CO coversion  \
# 0                  1.441673                 0.360241      0.532953
# 1                 -0.926417                -1.171090     -0.246477
# 2                  0.172068                 0.046016     -1.299123
# 3                 -0.875356                -0.994082      1.391436
# 4                  1.623833                -1.276747      1.126541
#
#    Voltage (V)  Electricity cost ($/kWh)  Membrain cost ($/m2)  \
# 0    -0.358187                  1.459581             -0.498390
# 1     0.537111                  0.955127              1.237291
# 2     1.189616                  0.946880             -1.165533
# 3    -0.278176                 -1.075060             -0.520536
# 4     0.286041                 -0.100515             -1.697034
#
#    Catpure energy (GJ/ton)  Crossover rate
# 0                 0.813698        1.450541
# 1                 1.564214        1.714248
# 2                 0.591017        1.447794
# 3                -0.795925        0.243260
# 4                 0.755966        1.473890

# %% [markdown]
# step3. MLP(ANN) 구조 설계 및 여러 신경망 층 구조에 대한 GridSearchCV 진행을 통해 최적 구조 찾기

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense
from scikeras.wrappers import KerasRegressor  # scikeras 권장
from sklearn.model_selection import GridSearchCV








# 1. 모델 생성 함수 / units1 = 은닉층 1층 / units2 = 은닉층2층
def create_ann_model(units1=32, units2=16, activation='relu'):
    model = Sequential([
        Input(shape=(8,)),             # 입력 특성 8개
        Dense(units1, activation=activation),
        Dense(units2, activation=activation),
        Dense(1, activation='linear')
    ])
    model.compile(
        optimizer='adam',
        loss='mean_squared_error',
        metrics=['mean_absolute_error']
    )
    return model


# 2. 래퍼 정의 (scikeras)
regressor = KerasRegressor(
    model=create_ann_model,    # 반드시 함수명만!
    verbose=0                  # fit epoch 로그 감춤
)



# 3. 모델 생성 및 구조 확인
# Required energy_total 예측 모델
#ann_model = create_ann_model()

# 모델의 구조를 요약하여 출력합니다.
#print("--- 'Required energy_total' 예측 모델 구조 ---")
#ann_model.summary()




# 3. GridSearch를 위한 파라미터 그리드 정의
param_grid = {
    'model__units1': [16, 32],      # 첫 은닉층 뉴런수 (은닉층1)
    'model__units2': [8, 16],       # 두 번째 은닉층 뉴런수 (은닉층2)
    'model__activation': ['relu', 'tanh'],
    'batch_size': [32],             # 배치 사이즈
    'epochs': [100],               # 학습 epoch 수 --- 50,100 이렇게 쓰기
}




# 4. GridSearchCV 객체 생성
grid = GridSearchCV(
    estimator=regressor,
    param_grid=param_grid,
    cv=3,                              # 3-fold 교차검증
    scoring='neg_mean_squared_error',  # MSE가 낮을수록 좋으니 음수로 반환
    n_jobs=-1
)

# 5. 학습 (여기서 Y_train_scaled.shape = (n_samples, 1)여야 함)
# scikit-learn의 GridSearchCV는 numpy array (2D 권장)
grid_result = grid.fit(X_train_scaled, Y_train_scaled)


# 6. 결과 출력
print("최적 하이퍼파라미터:", grid_result.best_params_)
print("최적 평균 검증 MSE:", -grid_result.best_score_)




# 7. 최적 파라미터 추출 / best_params에 다 저장이 되어있다
best_params = grid_result.best_params_
optimal_units1 = best_params['model__units1']
optimal_units2 = best_params['model__units2'] 
optimal_activation = best_params['model__activation']
optimal_batch_size = best_params['batch_size']


# GridSearchCV 결과 시각화
cv_results = pd.DataFrame(grid_result.cv_results_)
print("\n=== GridSearchCV 상세 결과 ===")
print(cv_results[['params', 'mean_test_score', 'std_test_score']].sort_values('mean_test_score', ascending=False))



# 8. 최적 파라미터로 모델 생성
def create_optimal_model():
    model = Sequential([
        Input(shape=(8,)),
        Dense(optimal_units1, activation=optimal_activation),
        Dense(optimal_units2, activation=optimal_activation),
        Dense(1, activation='linear')
    ])
    model.compile(
        optimizer='adam',
        loss='mean_squared_error',
        metrics=['mean_absolute_error']
    )
    return model

ann_model = create_optimal_model()

# 9. 최적 모델 구조 보여주기
print(f"최적 모델 구조:8- {optimal_units1}-{optimal_units2}, activation: {optimal_activation}, -1")




# 7. (선택) 결과 table을 보기 좋게 정리
#import pandas as pd
#cv_results = pd.DataFrame(grid_result.cv_results_)
#display(cv_results.sort_values('mean_test_score', ascending=False))
# Out:
# 최적 하이퍼파라미터: {'batch_size': 32, 'epochs': 100, 'model__activation': 'tanh', 'model__units1': 32, 'model__units2': 16}
# 최적 평균 검증 MSE: 0.14170034998642497
#
# === GridSearchCV 상세 결과 ===
#                                               params  mean_test_score  \
# 7  {'batch_size': 32, 'epochs': 100, 'model__acti...        -0.141700
# 6  {'batch_size': 32, 'epochs': 100, 'model__acti...        -0.142956
# 4  {'batch_size': 32, 'epochs': 100, 'model__acti...        -0.172008
# 5  {'batch_size': 32, 'epochs': 100, 'model__acti...        -0.209367
# 2  {'batch_size': 32, 'epochs': 100, 'model__acti...        -0.251417
# 3  {'batch_size': 32, 'epochs': 100, 'model__acti...        -0.253752
# 1  {'batch_size': 32, 'epochs': 100, 'model__acti...        -0.262755
# 0  {'batch_size': 32, 'epochs': 100, 'model__acti...        -0.265753
#
#    std_test_score
# 7        0.024397
# 6        0.027398
# 4        0.029506
# 5        0.054142
# 2        0.069375
# 3        0.057578
# 1        0.075883
# 0        0.030912
# 최적 모델 구조:8- 32-16, activation: tanh, -1

# %% [markdown]
# step4. MLP(ANN) 모델 컴파일

# %% [raw]
# # 1. 모델 컴파일
# # 모델이 어떻게 학습할지 학습 과정을 설정합니다.
# ann_model.compile(
#     optimizer='adam',
#     loss='mean_squared_error',
#     metrics=['mean_absolute_error']
# )
#
# # 2. 컴파일 완료 확인
# print("--- 모델 컴파일 완료 ---")
# print("최적화 알고리즘 (Optimizer): Adam")
# print("손실 함수 (Loss Function): Mean Squared Error (MSE)")
# print("평가 지표 (Metrics): Mean Absolute Error (MAE)")
#
# # 컴파일 후 모델 구조를 다시 한번 확인하여 최종 상태를 볼 수 있습니다.
# # 이 summary()는 컴파일 전과 내용은 동일하지만, 컴파일이 성공적으로 끝났음을 확인하는 의미가 있습니다.
# print("\n컴파일된 모델의 최종 구조:")
# ann_model.summary()

# %% [markdown]
# step4. 모델 학습 및 plot

# %%
# 1. 필요한 라이브러리 불러오기
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score
from tensorflow.keras.callbacks import EarlyStopping







# 2. 모델 학습 (Training)
print("--- 모델 학습을 시작합니다 ---")

early_stopping = EarlyStopping(
    monitor='val_loss',         # 검증 손실 기준
    patience=20,                # 개선되지 않는 epoch 10회 동안 기다리기(8~20 추천)
    restore_best_weights=True   # 가장 좋은 가중치로 복원
)


history = ann_model.fit(
    X_train_scaled, 
    Y_train_scaled,
    epochs=1000, #충분히 큰 값으로 설정
    batch_size=optimal_batch_size, #  # GridSearchCV 결과 활용
    validation_data=(X_val_scaled, Y_val_scaled),
    callbacks=[early_stopping],  # 콜백 추가 / overfitting 뜨기 전에 끊기
    verbose=1 # 학습 진행 로그를 상세하게 출력. (=에포크마다 손실/평가지표가 콘솔에 실시간 표시됨)
)
print("\n--- 모델 학습 완료 ---")









# 3. 모델 성능 평가 (Evaluation)
print("\n--- 테스트 데이터로 모델 성능을 평가합니다 ---")
test_loss, test_mae = ann_model.evaluate(X_test_scaled, Y_test_scaled, verbose=0)
print(f"테스트 데이터 손실 (MSE): {test_loss:.4f}")
print(f"테스트 데이터 평균 절대 오차 (MAE): {test_mae:.4f}")




# 4. 테스트 데이터 예측 및 R² 계산
Y_pred_scaled = ann_model.predict(X_test_scaled)
Y_pred = scaler_Y.inverse_transform(Y_pred_scaled)
Y_test_true = Y_test          # DataFrame에서 numpy로 변환

r2 = r2_score(Y_test_true, Y_pred)
print(f"테스트 데이터 결정계수 (R²): {r2:.4f}")

best_epoch = np.argmin(history.history['val_loss']) + 1  # 1-base
print(f"최적의 epoch: {best_epoch}")
print(f"최소 val_loss: {history.history['val_loss'][best_epoch-1]:.5f}")



# 5. 학습 과정 시각화 (Loss, MAE, R²)
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(21, 5))

# Loss
ax1.plot(history.history['loss'], label='Training Loss')
ax1.plot(history.history['val_loss'], label='Validation Loss')
ax1.set_title('Loss (MSE)')
ax1.set_xlabel('Epoch'); ax1.set_ylabel('Loss'); ax1.legend(); ax1.grid(True)

# MAE
ax2.plot(history.history['mean_absolute_error'], label='Training MAE')
ax2.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
ax2.set_title('Mean Absolute Error (MAE)')
ax2.set_xlabel('Epoch'); ax2.set_ylabel('MAE'); ax2.legend(); ax2.grid(True)

# R² 수기계산(별도 그래프)
ax3.plot([r2]*len(history.history['loss']), label=f'Test R² = {r2:.3f}')
ax3.set_title('Test R-squared')
ax3.set_xlabel('Epoch'); ax3.set_ylabel('R²'); ax3.legend(); ax3.grid(True)
ax3.set_ylim(bottom=0, top=1)

plt.tight_layout()
plt.show()




# 6. 실제값-예측값 산점도
plt.figure(figsize=(7,7))
plt.scatter(Y_test_true, Y_pred, alpha=0.5)
plt.plot([Y_test_true.min(), Y_test_true.max()],
         [Y_test_true.min(), Y_test_true.max()], 'r--', lw=2, label='Perfect')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title(f"Actual vs. Predicted (R² = {r2:.3f})")
plt.legend(); plt.grid(True); plt.axis('equal')
plt.show()




# 7. 잔차 플롯 (residuals)
residuals = (Y_test_true.flatten() - Y_pred.flatten())
plt.figure(figsize=(8,6))
plt.scatter(Y_pred, residuals, alpha=0.6)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals (Actual - Predicted)')
plt.title('Residual Plot')
plt.grid(True)
plt.show()


# 모델 성능 요약 
print(f"\n=== 최종 모델 성능 요약 ===")
print(f"모델 구조: 8-{optimal_units1}-{optimal_units2}-1")
print(f"활성화 함수: {optimal_activation}")
print(f"최적 epoch: {best_epoch}")
print(f"테스트 R²: {r2:.4f}")
print(f"테스트 MAE: {test_mae:.4f}")
# Out:
# --- 모델 학습을 시작합니다 ---
# Epoch 1/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.8170 - mean_absolute_error: 0.5142 - val_loss: 0.7595 - val_mean_absolute_error: 0.4559
# Epoch 2/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6697 - mean_absolute_error: 0.4540 - val_loss: 0.7590 - val_mean_absolute_error: 0.4356
# Epoch 3/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6992 - mean_absolute_error: 0.4466 - val_loss: 0.7498 - val_mean_absolute_error: 0.4361
# Epoch 4/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6815 - mean_absolute_error: 0.4378 - val_loss: 0.7473 - val_mean_absolute_error: 0.4382
# Epoch 5/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5328 - mean_absolute_error: 0.4124 - val_loss: 0.7436 - val_mean_absolute_error: 0.4591
# Epoch 6/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5307 - mean_absolute_error: 0.4046 - val_loss: 0.7469 - val_mean_absolute_error: 0.4531
# Epoch 7/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5289 - mean_absolute_error: 0.4105 - val_loss: 0.7334 - val_mean_absolute_error: 0.4455
# Epoch 8/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8064 - mean_absolute_error: 0.4462 - val_loss: 0.7264 - val_mean_absolute_error: 0.4355
# Epoch 9/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6385 - mean_absolute_error: 0.4217 - val_loss: 0.7142 - val_mean_absolute_error: 0.4252
# Epoch 10/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5257 - mean_absolute_error: 0.3993 - val_loss: 0.7025 - val_mean_absolute_error: 0.4324
# Epoch 11/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5278 - mean_absolute_error: 0.3860 - val_loss: 0.6911 - val_mean_absolute_error: 0.4153
# Epoch 12/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6263 - mean_absolute_error: 0.4144 - val_loss: 0.6798 - val_mean_absolute_error: 0.3949
# Epoch 13/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5316 - mean_absolute_error: 0.3581 - val_loss: 0.6570 - val_mean_absolute_error: 0.3985
# Epoch 14/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5003 - mean_absolute_error: 0.3651 - val_loss: 0.6384 - val_mean_absolute_error: 0.3769
# Epoch 15/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5182 - mean_absolute_error: 0.3739 - val_loss: 0.6226 - val_mean_absolute_error: 0.3709
# Epoch 16/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4035 - mean_absolute_error: 0.3229 - val_loss: 0.5989 - val_mean_absolute_error: 0.3552
# Epoch 17/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4320 - mean_absolute_error: 0.3253 - val_loss: 0.5793 - val_mean_absolute_error: 0.3447
# Epoch 18/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.3856 - mean_absolute_error: 0.2874 - val_loss: 0.5599 - val_mean_absolute_error: 0.3544
# Epoch 19/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.3733 - mean_absolute_error: 0.2921 - val_loss: 0.5370 - val_mean_absolute_error: 0.3227
# Epoch 20/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.6081 - mean_absolute_error: 0.3331 - val_loss: 0.5235 - val_mean_absolute_error: 0.2895
# Epoch 21/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5927 - mean_absolute_error: 0.3124 - val_loss: 0.5070 - val_mean_absolute_error: 0.2772
# Epoch 22/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4866 - mean_absolute_error: 0.2891 - val_loss: 0.4884 - val_mean_absolute_error: 0.2650
# Epoch 23/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.3536 - mean_absolute_error: 0.2381 - val_loss: 0.4619 - val_mean_absolute_error: 0.2886
# Epoch 24/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4460 - mean_absolute_error: 0.2797 - val_loss: 0.4463 - val_mean_absolute_error: 0.2644
# Epoch 25/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3160 - mean_absolute_error: 0.2331 - val_loss: 0.4263 - val_mean_absolute_error: 0.2729
# Epoch 26/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4633 - mean_absolute_error: 0.2745 - val_loss: 0.4135 - val_mean_absolute_error: 0.2437
# Epoch 27/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2922 - mean_absolute_error: 0.2095 - val_loss: 0.3928 - val_mean_absolute_error: 0.2507
# Epoch 28/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2961 - mean_absolute_error: 0.2243 - val_loss: 0.3943 - val_mean_absolute_error: 0.2215
# Epoch 29/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.3055 - mean_absolute_error: 0.1975 - val_loss: 0.3585 - val_mean_absolute_error: 0.2398
# Epoch 30/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.3273 - mean_absolute_error: 0.2232 - val_loss: 0.3820 - val_mean_absolute_error: 0.2054
# Epoch 31/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.3082 - mean_absolute_error: 0.1946 - val_loss: 0.3413 - val_mean_absolute_error: 0.2178
# Epoch 32/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.3763 - mean_absolute_error: 0.2147 - val_loss: 0.3202 - val_mean_absolute_error: 0.2074
# Epoch 33/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2118 - mean_absolute_error: 0.1768 - val_loss: 0.3086 - val_mean_absolute_error: 0.2230
# Epoch 34/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.3094 - mean_absolute_error: 0.2123 - val_loss: 0.3014 - val_mean_absolute_error: 0.2093
# Epoch 35/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1947 - mean_absolute_error: 0.1742 - val_loss: 0.2912 - val_mean_absolute_error: 0.2190
# Epoch 36/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2027 - mean_absolute_error: 0.1796 - val_loss: 0.2813 - val_mean_absolute_error: 0.1889
# Epoch 37/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1782 - mean_absolute_error: 0.1623 - val_loss: 0.2682 - val_mean_absolute_error: 0.1862
# Epoch 38/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1928 - mean_absolute_error: 0.1706 - val_loss: 0.2587 - val_mean_absolute_error: 0.1944
# Epoch 39/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1595 - mean_absolute_error: 0.1597 - val_loss: 0.2498 - val_mean_absolute_error: 0.1899
# Epoch 40/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2276 - mean_absolute_error: 0.1814 - val_loss: 0.2582 - val_mean_absolute_error: 0.1650
# Epoch 41/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1782 - mean_absolute_error: 0.1473 - val_loss: 0.2425 - val_mean_absolute_error: 0.1659
# Epoch 42/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1890 - mean_absolute_error: 0.1604 - val_loss: 0.2399 - val_mean_absolute_error: 0.1670
# Epoch 43/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2057 - mean_absolute_error: 0.1631 - val_loss: 0.2297 - val_mean_absolute_error: 0.1533
# Epoch 44/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1413 - mean_absolute_error: 0.1487 - val_loss: 0.2182 - val_mean_absolute_error: 0.1638
# Epoch 45/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2000 - mean_absolute_error: 0.1661 - val_loss: 0.2358 - val_mean_absolute_error: 0.1459
# Epoch 46/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1338 - mean_absolute_error: 0.1329 - val_loss: 0.2072 - val_mean_absolute_error: 0.1564
# Epoch 47/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1472 - mean_absolute_error: 0.1485 - val_loss: 0.2350 - val_mean_absolute_error: 0.1441
# Epoch 48/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1305 - mean_absolute_error: 0.1336 - val_loss: 0.1969 - val_mean_absolute_error: 0.1491
# Epoch 49/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1292 - mean_absolute_error: 0.1342 - val_loss: 0.1916 - val_mean_absolute_error: 0.1482
# Epoch 50/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1327 - mean_absolute_error: 0.1317 - val_loss: 0.1950 - val_mean_absolute_error: 0.1452
# Epoch 51/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1538 - mean_absolute_error: 0.1263 - val_loss: 0.1838 - val_mean_absolute_error: 0.1529
# Epoch 52/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1301 - mean_absolute_error: 0.1260 - val_loss: 0.1944 - val_mean_absolute_error: 0.1358
# Epoch 53/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0765 - mean_absolute_error: 0.1107 - val_loss: 0.1730 - val_mean_absolute_error: 0.1535
# Epoch 54/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1775 - mean_absolute_error: 0.1536 - val_loss: 0.1789 - val_mean_absolute_error: 0.1338
# Epoch 55/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1229 - mean_absolute_error: 0.1183 - val_loss: 0.1821 - val_mean_absolute_error: 0.1362
# Epoch 56/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1315 - mean_absolute_error: 0.1234 - val_loss: 0.1744 - val_mean_absolute_error: 0.1292
# Epoch 57/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0940 - mean_absolute_error: 0.1134 - val_loss: 0.2086 - val_mean_absolute_error: 0.1312
# Epoch 58/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1017 - mean_absolute_error: 0.1133 - val_loss: 0.1555 - val_mean_absolute_error: 0.1316
# Epoch 59/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0823 - mean_absolute_error: 0.1105 - val_loss: 0.1573 - val_mean_absolute_error: 0.1348
# Epoch 60/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0906 - mean_absolute_error: 0.1107 - val_loss: 0.1592 - val_mean_absolute_error: 0.1301
# Epoch 61/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1509 - mean_absolute_error: 0.1210 - val_loss: 0.1684 - val_mean_absolute_error: 0.1239
# Epoch 62/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0645 - mean_absolute_error: 0.0999 - val_loss: 0.1525 - val_mean_absolute_error: 0.1524
# Epoch 63/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1244 - mean_absolute_error: 0.1306 - val_loss: 0.1458 - val_mean_absolute_error: 0.1245
# Epoch 64/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0776 - mean_absolute_error: 0.0989 - val_loss: 0.1407 - val_mean_absolute_error: 0.1234
# Epoch 65/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0764 - mean_absolute_error: 0.1010 - val_loss: 0.1384 - val_mean_absolute_error: 0.1254
# Epoch 66/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1107 - mean_absolute_error: 0.1175 - val_loss: 0.1473 - val_mean_absolute_error: 0.1166
# Epoch 67/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0989 - mean_absolute_error: 0.1048 - val_loss: 0.1587 - val_mean_absolute_error: 0.1205
# Epoch 68/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0944 - mean_absolute_error: 0.1039 - val_loss: 0.1396 - val_mean_absolute_error: 0.1183
# Epoch 69/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1183 - mean_absolute_error: 0.1165 - val_loss: 0.1267 - val_mean_absolute_error: 0.1161
# Epoch 70/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0973 - mean_absolute_error: 0.1057 - val_loss: 0.1470 - val_mean_absolute_error: 0.1179
# Epoch 71/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0986 - mean_absolute_error: 0.1006 - val_loss: 0.1472 - val_mean_absolute_error: 0.1190
# Epoch 72/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0861 - mean_absolute_error: 0.0960 - val_loss: 0.1298 - val_mean_absolute_error: 0.1119
# Epoch 73/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0842 - mean_absolute_error: 0.0948 - val_loss: 0.1272 - val_mean_absolute_error: 0.1121
# Epoch 74/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0676 - mean_absolute_error: 0.0919 - val_loss: 0.1361 - val_mean_absolute_error: 0.1185
# Epoch 75/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0831 - mean_absolute_error: 0.1020 - val_loss: 0.1302 - val_mean_absolute_error: 0.1085
# Epoch 76/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0687 - mean_absolute_error: 0.0888 - val_loss: 0.1175 - val_mean_absolute_error: 0.1085
# Epoch 77/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0715 - mean_absolute_error: 0.0860 - val_loss: 0.1155 - val_mean_absolute_error: 0.1097
# Epoch 78/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0646 - mean_absolute_error: 0.0916 - val_loss: 0.1156 - val_mean_absolute_error: 0.1133
# Epoch 79/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0637 - mean_absolute_error: 0.0897 - val_loss: 0.1169 - val_mean_absolute_error: 0.1043
# Epoch 80/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0538 - mean_absolute_error: 0.0870 - val_loss: 0.1178 - val_mean_absolute_error: 0.1016
# Epoch 81/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0628 - mean_absolute_error: 0.0831 - val_loss: 0.1439 - val_mean_absolute_error: 0.1116
# Epoch 82/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0635 - mean_absolute_error: 0.0899 - val_loss: 0.1109 - val_mean_absolute_error: 0.1075
# Epoch 83/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0659 - mean_absolute_error: 0.0871 - val_loss: 0.1086 - val_mean_absolute_error: 0.1012
# Epoch 84/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0609 - mean_absolute_error: 0.0822 - val_loss: 0.1287 - val_mean_absolute_error: 0.1053
# Epoch 85/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0506 - mean_absolute_error: 0.0788 - val_loss: 0.1116 - val_mean_absolute_error: 0.1042
# Epoch 86/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0440 - mean_absolute_error: 0.0799 - val_loss: 0.0981 - val_mean_absolute_error: 0.1028
# Epoch 87/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0579 - mean_absolute_error: 0.0769 - val_loss: 0.0989 - val_mean_absolute_error: 0.0995
# Epoch 88/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0698 - mean_absolute_error: 0.0868 - val_loss: 0.1137 - val_mean_absolute_error: 0.1035
# Epoch 89/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0552 - mean_absolute_error: 0.0801 - val_loss: 0.1198 - val_mean_absolute_error: 0.1035
# Epoch 90/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0534 - mean_absolute_error: 0.0803 - val_loss: 0.1112 - val_mean_absolute_error: 0.1032
# Epoch 91/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0436 - mean_absolute_error: 0.0749 - val_loss: 0.1015 - val_mean_absolute_error: 0.0984
# Epoch 92/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0523 - mean_absolute_error: 0.0778 - val_loss: 0.0908 - val_mean_absolute_error: 0.0969
# Epoch 93/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0460 - mean_absolute_error: 0.0761 - val_loss: 0.1062 - val_mean_absolute_error: 0.0988
# Epoch 94/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0482 - mean_absolute_error: 0.0727 - val_loss: 0.0929 - val_mean_absolute_error: 0.0952
# Epoch 95/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0364 - mean_absolute_error: 0.0657 - val_loss: 0.0901 - val_mean_absolute_error: 0.0917
# Epoch 96/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0455 - mean_absolute_error: 0.0733 - val_loss: 0.0990 - val_mean_absolute_error: 0.0942
# Epoch 97/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0376 - mean_absolute_error: 0.0726 - val_loss: 0.0902 - val_mean_absolute_error: 0.0993
# Epoch 98/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0488 - mean_absolute_error: 0.0754 - val_loss: 0.0848 - val_mean_absolute_error: 0.0935
# Epoch 99/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0437 - mean_absolute_error: 0.0718 - val_loss: 0.0951 - val_mean_absolute_error: 0.0960
# Epoch 100/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0384 - mean_absolute_error: 0.0693 - val_loss: 0.0914 - val_mean_absolute_error: 0.0971
# Epoch 101/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0419 - mean_absolute_error: 0.0721 - val_loss: 0.1072 - val_mean_absolute_error: 0.0955
# Epoch 102/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0446 - mean_absolute_error: 0.0736 - val_loss: 0.0869 - val_mean_absolute_error: 0.0930
# Epoch 103/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0567 - mean_absolute_error: 0.0806 - val_loss: 0.0877 - val_mean_absolute_error: 0.0986
# Epoch 104/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mean_absolute_error: 0.0730 - val_loss: 0.0893 - val_mean_absolute_error: 0.0911
# Epoch 105/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0517 - mean_absolute_error: 0.0721 - val_loss: 0.0975 - val_mean_absolute_error: 0.0916
# Epoch 106/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0446 - mean_absolute_error: 0.0654 - val_loss: 0.0918 - val_mean_absolute_error: 0.0892
# Epoch 107/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0691 - mean_absolute_error: 0.0829 - val_loss: 0.1030 - val_mean_absolute_error: 0.0940
# Epoch 108/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0427 - mean_absolute_error: 0.0688 - val_loss: 0.1131 - val_mean_absolute_error: 0.1113
# Epoch 109/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0365 - mean_absolute_error: 0.0689 - val_loss: 0.0873 - val_mean_absolute_error: 0.0887
# Epoch 110/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0671 - mean_absolute_error: 0.0892 - val_loss: 0.0842 - val_mean_absolute_error: 0.1011
# Epoch 111/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0434 - mean_absolute_error: 0.0726 - val_loss: 0.0979 - val_mean_absolute_error: 0.0936
# Epoch 112/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0266 - mean_absolute_error: 0.0641 - val_loss: 0.0760 - val_mean_absolute_error: 0.0898
# Epoch 113/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0394 - mean_absolute_error: 0.0706 - val_loss: 0.0931 - val_mean_absolute_error: 0.0911
# Epoch 114/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0253 - mean_absolute_error: 0.0568 - val_loss: 0.0821 - val_mean_absolute_error: 0.0889
# Epoch 115/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0514 - mean_absolute_error: 0.0750 - val_loss: 0.0889 - val_mean_absolute_error: 0.0919
# Epoch 116/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0421 - mean_absolute_error: 0.0693 - val_loss: 0.0835 - val_mean_absolute_error: 0.0851
# Epoch 117/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0427 - mean_absolute_error: 0.0694 - val_loss: 0.0749 - val_mean_absolute_error: 0.0873
# Epoch 118/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0405 - mean_absolute_error: 0.0686 - val_loss: 0.0801 - val_mean_absolute_error: 0.0864
# Epoch 119/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0190 - mean_absolute_error: 0.0536 - val_loss: 0.0766 - val_mean_absolute_error: 0.0817
# Epoch 120/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0416 - mean_absolute_error: 0.0671 - val_loss: 0.0769 - val_mean_absolute_error: 0.0838
# Epoch 121/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0369 - mean_absolute_error: 0.0625 - val_loss: 0.0712 - val_mean_absolute_error: 0.0787
# Epoch 122/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0280 - mean_absolute_error: 0.0559 - val_loss: 0.0698 - val_mean_absolute_error: 0.0809
# Epoch 123/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0319 - mean_absolute_error: 0.0622 - val_loss: 0.0824 - val_mean_absolute_error: 0.0882
# Epoch 124/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0295 - mean_absolute_error: 0.0609 - val_loss: 0.0926 - val_mean_absolute_error: 0.0868
# Epoch 125/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0422 - mean_absolute_error: 0.0692 - val_loss: 0.0765 - val_mean_absolute_error: 0.0944
# Epoch 126/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0567 - mean_absolute_error: 0.0845 - val_loss: 0.0650 - val_mean_absolute_error: 0.0885
# Epoch 127/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0358 - mean_absolute_error: 0.0645 - val_loss: 0.0697 - val_mean_absolute_error: 0.0779
# Epoch 128/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0349 - mean_absolute_error: 0.0599 - val_loss: 0.0677 - val_mean_absolute_error: 0.0789
# Epoch 129/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mean_absolute_error: 0.0635 - val_loss: 0.0753 - val_mean_absolute_error: 0.0830
# Epoch 130/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0330 - mean_absolute_error: 0.0642 - val_loss: 0.0667 - val_mean_absolute_error: 0.0760
# Epoch 131/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0320 - mean_absolute_error: 0.0616 - val_loss: 0.0682 - val_mean_absolute_error: 0.0808
# Epoch 132/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0423 - mean_absolute_error: 0.0677 - val_loss: 0.0702 - val_mean_absolute_error: 0.0814
# Epoch 133/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0208 - mean_absolute_error: 0.0528 - val_loss: 0.0916 - val_mean_absolute_error: 0.0931
# Epoch 134/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0323 - mean_absolute_error: 0.0675 - val_loss: 0.0736 - val_mean_absolute_error: 0.0789
# Epoch 135/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0265 - mean_absolute_error: 0.0544 - val_loss: 0.0650 - val_mean_absolute_error: 0.0749
# Epoch 136/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0315 - mean_absolute_error: 0.0599 - val_loss: 0.0734 - val_mean_absolute_error: 0.0886
# Epoch 137/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0286 - mean_absolute_error: 0.0584 - val_loss: 0.0667 - val_mean_absolute_error: 0.0756
# Epoch 138/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0282 - mean_absolute_error: 0.0582 - val_loss: 0.0717 - val_mean_absolute_error: 0.0842
# Epoch 139/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0385 - mean_absolute_error: 0.0662 - val_loss: 0.0674 - val_mean_absolute_error: 0.0785
# Epoch 140/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0418 - mean_absolute_error: 0.0629 - val_loss: 0.0674 - val_mean_absolute_error: 0.0771
# Epoch 141/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0288 - mean_absolute_error: 0.0562 - val_loss: 0.0954 - val_mean_absolute_error: 0.0904
# Epoch 142/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0426 - mean_absolute_error: 0.0789 - val_loss: 0.0897 - val_mean_absolute_error: 0.1036
# Epoch 143/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0444 - mean_absolute_error: 0.0713 - val_loss: 0.0637 - val_mean_absolute_error: 0.0739
# Epoch 144/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0392 - mean_absolute_error: 0.0573 - val_loss: 0.0644 - val_mean_absolute_error: 0.0742
# Epoch 145/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0331 - mean_absolute_error: 0.0617 - val_loss: 0.0619 - val_mean_absolute_error: 0.0769
# Epoch 146/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0298 - mean_absolute_error: 0.0576 - val_loss: 0.0649 - val_mean_absolute_error: 0.0753
# Epoch 147/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0212 - mean_absolute_error: 0.0526 - val_loss: 0.0652 - val_mean_absolute_error: 0.0736
# Epoch 148/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0238 - mean_absolute_error: 0.0506 - val_loss: 0.0596 - val_mean_absolute_error: 0.0716
# Epoch 149/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0241 - mean_absolute_error: 0.0572 - val_loss: 0.0729 - val_mean_absolute_error: 0.0790
# Epoch 150/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0366 - mean_absolute_error: 0.0600 - val_loss: 0.0612 - val_mean_absolute_error: 0.0723
# Epoch 151/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0165 - mean_absolute_error: 0.0471 - val_loss: 0.0558 - val_mean_absolute_error: 0.0704
# Epoch 152/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0291 - mean_absolute_error: 0.0571 - val_loss: 0.0966 - val_mean_absolute_error: 0.0939
# Epoch 153/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0490 - mean_absolute_error: 0.0774 - val_loss: 0.0564 - val_mean_absolute_error: 0.0748
# Epoch 154/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0226 - mean_absolute_error: 0.0518 - val_loss: 0.0711 - val_mean_absolute_error: 0.0806
# Epoch 155/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0240 - mean_absolute_error: 0.0563 - val_loss: 0.0648 - val_mean_absolute_error: 0.0745
# Epoch 156/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0223 - mean_absolute_error: 0.0553 - val_loss: 0.0587 - val_mean_absolute_error: 0.0723
# Epoch 157/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0411 - mean_absolute_error: 0.0620 - val_loss: 0.0532 - val_mean_absolute_error: 0.0663
# Epoch 158/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0328 - mean_absolute_error: 0.0596 - val_loss: 0.0579 - val_mean_absolute_error: 0.0719
# Epoch 159/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0258 - mean_absolute_error: 0.0549 - val_loss: 0.0553 - val_mean_absolute_error: 0.0684
# Epoch 160/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0255 - mean_absolute_error: 0.0579 - val_loss: 0.0585 - val_mean_absolute_error: 0.0771
# Epoch 161/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0449 - mean_absolute_error: 0.0712 - val_loss: 0.0642 - val_mean_absolute_error: 0.0736
# Epoch 162/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0162 - mean_absolute_error: 0.0489 - val_loss: 0.0599 - val_mean_absolute_error: 0.0696
# Epoch 163/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0140 - mean_absolute_error: 0.0437 - val_loss: 0.0661 - val_mean_absolute_error: 0.0761
# Epoch 164/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0247 - mean_absolute_error: 0.0516 - val_loss: 0.0487 - val_mean_absolute_error: 0.0651
# Epoch 165/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0217 - mean_absolute_error: 0.0550 - val_loss: 0.0605 - val_mean_absolute_error: 0.0767
# Epoch 166/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0290 - mean_absolute_error: 0.0582 - val_loss: 0.0743 - val_mean_absolute_error: 0.0799
# Epoch 167/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0293 - mean_absolute_error: 0.0559 - val_loss: 0.0508 - val_mean_absolute_error: 0.0659
# Epoch 168/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0338 - mean_absolute_error: 0.0557 - val_loss: 0.0607 - val_mean_absolute_error: 0.0724
# Epoch 169/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0314 - mean_absolute_error: 0.0631 - val_loss: 0.0705 - val_mean_absolute_error: 0.0744
# Epoch 170/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0359 - mean_absolute_error: 0.0560 - val_loss: 0.0525 - val_mean_absolute_error: 0.0681
# Epoch 171/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0165 - mean_absolute_error: 0.0464 - val_loss: 0.0577 - val_mean_absolute_error: 0.0700
# Epoch 172/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0210 - mean_absolute_error: 0.0504 - val_loss: 0.0505 - val_mean_absolute_error: 0.0652
# Epoch 173/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0205 - mean_absolute_error: 0.0483 - val_loss: 0.0479 - val_mean_absolute_error: 0.0676
# Epoch 174/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0167 - mean_absolute_error: 0.0498 - val_loss: 0.0545 - val_mean_absolute_error: 0.0704
# Epoch 175/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0242 - mean_absolute_error: 0.0576 - val_loss: 0.0616 - val_mean_absolute_error: 0.0795
# Epoch 176/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0286 - mean_absolute_error: 0.0607 - val_loss: 0.0513 - val_mean_absolute_error: 0.0687
# Epoch 177/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0144 - mean_absolute_error: 0.0448 - val_loss: 0.0550 - val_mean_absolute_error: 0.0706
# Epoch 178/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0246 - mean_absolute_error: 0.0511 - val_loss: 0.0507 - val_mean_absolute_error: 0.0670
# Epoch 179/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0295 - mean_absolute_error: 0.0549 - val_loss: 0.0537 - val_mean_absolute_error: 0.0657
# Epoch 180/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0116 - mean_absolute_error: 0.0420 - val_loss: 0.0539 - val_mean_absolute_error: 0.0696
# Epoch 181/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0246 - mean_absolute_error: 0.0591 - val_loss: 0.0603 - val_mean_absolute_error: 0.0778
# Epoch 182/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0222 - mean_absolute_error: 0.0555 - val_loss: 0.0511 - val_mean_absolute_error: 0.0674
# Epoch 183/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0196 - mean_absolute_error: 0.0473 - val_loss: 0.0437 - val_mean_absolute_error: 0.0644
# Epoch 184/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0180 - mean_absolute_error: 0.0491 - val_loss: 0.0503 - val_mean_absolute_error: 0.0681
# Epoch 185/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0192 - mean_absolute_error: 0.0487 - val_loss: 0.0453 - val_mean_absolute_error: 0.0685
# Epoch 186/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0180 - mean_absolute_error: 0.0513 - val_loss: 0.0571 - val_mean_absolute_error: 0.0767
# Epoch 187/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0176 - mean_absolute_error: 0.0488 - val_loss: 0.0564 - val_mean_absolute_error: 0.0666
# Epoch 188/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0177 - mean_absolute_error: 0.0457 - val_loss: 0.0501 - val_mean_absolute_error: 0.0725
# Epoch 189/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0223 - mean_absolute_error: 0.0580 - val_loss: 0.0480 - val_mean_absolute_error: 0.0644
# Epoch 190/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0168 - mean_absolute_error: 0.0482 - val_loss: 0.0460 - val_mean_absolute_error: 0.0650
# Epoch 191/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0178 - mean_absolute_error: 0.0499 - val_loss: 0.0421 - val_mean_absolute_error: 0.0610
# Epoch 192/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0254 - mean_absolute_error: 0.0545 - val_loss: 0.0389 - val_mean_absolute_error: 0.0596
# Epoch 193/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0251 - mean_absolute_error: 0.0524 - val_loss: 0.0567 - val_mean_absolute_error: 0.0726
# Epoch 194/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0303 - mean_absolute_error: 0.0627 - val_loss: 0.0477 - val_mean_absolute_error: 0.0672
# Epoch 195/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0204 - mean_absolute_error: 0.0524 - val_loss: 0.0539 - val_mean_absolute_error: 0.0635
# Epoch 196/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0229 - mean_absolute_error: 0.0481 - val_loss: 0.0445 - val_mean_absolute_error: 0.0630
# Epoch 197/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0179 - mean_absolute_error: 0.0426 - val_loss: 0.0772 - val_mean_absolute_error: 0.0842
# Epoch 198/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0185 - mean_absolute_error: 0.0570 - val_loss: 0.0446 - val_mean_absolute_error: 0.0632
# Epoch 199/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0198 - mean_absolute_error: 0.0476 - val_loss: 0.0417 - val_mean_absolute_error: 0.0595
# Epoch 200/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0134 - mean_absolute_error: 0.0407 - val_loss: 0.0394 - val_mean_absolute_error: 0.0595
# Epoch 201/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0206 - mean_absolute_error: 0.0486 - val_loss: 0.0398 - val_mean_absolute_error: 0.0646
# Epoch 202/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0246 - mean_absolute_error: 0.0607 - val_loss: 0.0483 - val_mean_absolute_error: 0.0702
# Epoch 203/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0353 - mean_absolute_error: 0.0680 - val_loss: 0.0406 - val_mean_absolute_error: 0.0629
# Epoch 204/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0189 - mean_absolute_error: 0.0500 - val_loss: 0.0491 - val_mean_absolute_error: 0.0642
# Epoch 205/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0099 - mean_absolute_error: 0.0402 - val_loss: 0.0412 - val_mean_absolute_error: 0.0583
# Epoch 206/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0160 - mean_absolute_error: 0.0453 - val_loss: 0.0446 - val_mean_absolute_error: 0.0775
# Epoch 207/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0162 - mean_absolute_error: 0.0497 - val_loss: 0.0356 - val_mean_absolute_error: 0.0589
# Epoch 208/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0311 - mean_absolute_error: 0.0590 - val_loss: 0.0362 - val_mean_absolute_error: 0.0610
# Epoch 209/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0194 - mean_absolute_error: 0.0499 - val_loss: 0.0386 - val_mean_absolute_error: 0.0569
# Epoch 210/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0110 - mean_absolute_error: 0.0434 - val_loss: 0.0430 - val_mean_absolute_error: 0.0593
# Epoch 211/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0219 - mean_absolute_error: 0.0514 - val_loss: 0.0547 - val_mean_absolute_error: 0.0680
# Epoch 212/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0251 - mean_absolute_error: 0.0505 - val_loss: 0.0430 - val_mean_absolute_error: 0.0620
# Epoch 213/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0154 - mean_absolute_error: 0.0453 - val_loss: 0.0431 - val_mean_absolute_error: 0.0595
# Epoch 214/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0181 - mean_absolute_error: 0.0479 - val_loss: 0.0437 - val_mean_absolute_error: 0.0648
# Epoch 215/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - mean_absolute_error: 0.0352 - val_loss: 0.0499 - val_mean_absolute_error: 0.0623
# Epoch 216/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0285 - mean_absolute_error: 0.0555 - val_loss: 0.0469 - val_mean_absolute_error: 0.0655
# Epoch 217/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0196 - mean_absolute_error: 0.0466 - val_loss: 0.0345 - val_mean_absolute_error: 0.0656
# Epoch 218/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0239 - mean_absolute_error: 0.0503 - val_loss: 0.0448 - val_mean_absolute_error: 0.0593
# Epoch 219/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0157 - mean_absolute_error: 0.0437 - val_loss: 0.0474 - val_mean_absolute_error: 0.0682
# Epoch 220/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0119 - mean_absolute_error: 0.0426 - val_loss: 0.0331 - val_mean_absolute_error: 0.0540
# Epoch 221/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0097 - mean_absolute_error: 0.0394 - val_loss: 0.0399 - val_mean_absolute_error: 0.0640
# Epoch 222/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0217 - mean_absolute_error: 0.0516 - val_loss: 0.0419 - val_mean_absolute_error: 0.0595
# Epoch 223/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - mean_absolute_error: 0.0425 - val_loss: 0.0445 - val_mean_absolute_error: 0.0698
# Epoch 224/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0185 - mean_absolute_error: 0.0490 - val_loss: 0.0341 - val_mean_absolute_error: 0.0548
# Epoch 225/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0160 - mean_absolute_error: 0.0443 - val_loss: 0.0314 - val_mean_absolute_error: 0.0523
# Epoch 226/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0124 - mean_absolute_error: 0.0468 - val_loss: 0.0358 - val_mean_absolute_error: 0.0611
# Epoch 227/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0124 - mean_absolute_error: 0.0453 - val_loss: 0.0327 - val_mean_absolute_error: 0.0548
# Epoch 228/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0191 - mean_absolute_error: 0.0458 - val_loss: 0.0370 - val_mean_absolute_error: 0.0603
# Epoch 229/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0207 - mean_absolute_error: 0.0443 - val_loss: 0.0292 - val_mean_absolute_error: 0.0529
# Epoch 230/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0113 - mean_absolute_error: 0.0433 - val_loss: 0.0367 - val_mean_absolute_error: 0.0557
# Epoch 231/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0102 - mean_absolute_error: 0.0395 - val_loss: 0.0441 - val_mean_absolute_error: 0.0611
# Epoch 232/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0114 - mean_absolute_error: 0.0453 - val_loss: 0.0437 - val_mean_absolute_error: 0.0640
# Epoch 233/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0138 - mean_absolute_error: 0.0421 - val_loss: 0.0339 - val_mean_absolute_error: 0.0525
# Epoch 234/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0100 - mean_absolute_error: 0.0392 - val_loss: 0.0387 - val_mean_absolute_error: 0.0591
# Epoch 235/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0121 - mean_absolute_error: 0.0405 - val_loss: 0.0322 - val_mean_absolute_error: 0.0659
# Epoch 236/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0221 - mean_absolute_error: 0.0548 - val_loss: 0.0424 - val_mean_absolute_error: 0.0564
# Epoch 237/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mean_absolute_error: 0.0476 - val_loss: 0.0595 - val_mean_absolute_error: 0.0671
# Epoch 238/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0171 - mean_absolute_error: 0.0523 - val_loss: 0.0353 - val_mean_absolute_error: 0.0538
# Epoch 239/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0193 - mean_absolute_error: 0.0463 - val_loss: 0.0332 - val_mean_absolute_error: 0.0555
# Epoch 240/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0141 - mean_absolute_error: 0.0431 - val_loss: 0.0374 - val_mean_absolute_error: 0.0547
# Epoch 241/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0089 - mean_absolute_error: 0.0384 - val_loss: 0.0383 - val_mean_absolute_error: 0.0555
# Epoch 242/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0141 - mean_absolute_error: 0.0391 - val_loss: 0.0337 - val_mean_absolute_error: 0.0559
# Epoch 243/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0152 - mean_absolute_error: 0.0443 - val_loss: 0.0338 - val_mean_absolute_error: 0.0535
# Epoch 244/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0127 - mean_absolute_error: 0.0421 - val_loss: 0.0503 - val_mean_absolute_error: 0.0583
# Epoch 245/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0134 - mean_absolute_error: 0.0439 - val_loss: 0.0292 - val_mean_absolute_error: 0.0514
# Epoch 246/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0098 - mean_absolute_error: 0.0399 - val_loss: 0.0260 - val_mean_absolute_error: 0.0536
# Epoch 247/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0121 - mean_absolute_error: 0.0392 - val_loss: 0.0470 - val_mean_absolute_error: 0.0580
# Epoch 248/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0174 - mean_absolute_error: 0.0478 - val_loss: 0.0356 - val_mean_absolute_error: 0.0517
# Epoch 249/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0125 - mean_absolute_error: 0.0392 - val_loss: 0.0381 - val_mean_absolute_error: 0.0583
# Epoch 250/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0080 - mean_absolute_error: 0.0353 - val_loss: 0.0294 - val_mean_absolute_error: 0.0559
# Epoch 251/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0214 - mean_absolute_error: 0.0555 - val_loss: 0.0313 - val_mean_absolute_error: 0.0545
# Epoch 252/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0153 - mean_absolute_error: 0.0408 - val_loss: 0.0372 - val_mean_absolute_error: 0.0596
# Epoch 253/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0216 - mean_absolute_error: 0.0510 - val_loss: 0.0297 - val_mean_absolute_error: 0.0517
# Epoch 254/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0201 - mean_absolute_error: 0.0458 - val_loss: 0.0341 - val_mean_absolute_error: 0.0591
# Epoch 255/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0128 - mean_absolute_error: 0.0424 - val_loss: 0.0298 - val_mean_absolute_error: 0.0534
# Epoch 256/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0189 - mean_absolute_error: 0.0464 - val_loss: 0.0344 - val_mean_absolute_error: 0.0593
# Epoch 257/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0135 - mean_absolute_error: 0.0436 - val_loss: 0.0257 - val_mean_absolute_error: 0.0519
# Epoch 258/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0067 - mean_absolute_error: 0.0358 - val_loss: 0.0238 - val_mean_absolute_error: 0.0507
# Epoch 259/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0168 - mean_absolute_error: 0.0425 - val_loss: 0.0280 - val_mean_absolute_error: 0.0523
# Epoch 260/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0108 - mean_absolute_error: 0.0430 - val_loss: 0.0446 - val_mean_absolute_error: 0.0608
# Epoch 261/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0132 - mean_absolute_error: 0.0429 - val_loss: 0.0313 - val_mean_absolute_error: 0.0525
# Epoch 262/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0263 - mean_absolute_error: 0.0516 - val_loss: 0.0963 - val_mean_absolute_error: 0.0908
# Epoch 263/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0318 - mean_absolute_error: 0.0652 - val_loss: 0.0389 - val_mean_absolute_error: 0.0613
# Epoch 264/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0267 - mean_absolute_error: 0.0512 - val_loss: 0.0559 - val_mean_absolute_error: 0.0640
# Epoch 265/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0212 - mean_absolute_error: 0.0503 - val_loss: 0.0294 - val_mean_absolute_error: 0.0503
# Epoch 266/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0083 - mean_absolute_error: 0.0352 - val_loss: 0.0354 - val_mean_absolute_error: 0.0534
# Epoch 267/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0192 - mean_absolute_error: 0.0436 - val_loss: 0.0342 - val_mean_absolute_error: 0.0516
# Epoch 268/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0148 - mean_absolute_error: 0.0469 - val_loss: 0.0300 - val_mean_absolute_error: 0.0492
# Epoch 269/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0133 - mean_absolute_error: 0.0407 - val_loss: 0.0448 - val_mean_absolute_error: 0.0675
# Epoch 270/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0144 - mean_absolute_error: 0.0475 - val_loss: 0.0313 - val_mean_absolute_error: 0.0507
# Epoch 271/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0114 - mean_absolute_error: 0.0378 - val_loss: 0.0406 - val_mean_absolute_error: 0.0606
# Epoch 272/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0127 - mean_absolute_error: 0.0463 - val_loss: 0.0335 - val_mean_absolute_error: 0.0543
# Epoch 273/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0107 - mean_absolute_error: 0.0366 - val_loss: 0.0283 - val_mean_absolute_error: 0.0479
# Epoch 274/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0107 - mean_absolute_error: 0.0362 - val_loss: 0.0392 - val_mean_absolute_error: 0.0536
# Epoch 275/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0203 - mean_absolute_error: 0.0449 - val_loss: 0.0281 - val_mean_absolute_error: 0.0504
# Epoch 276/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0158 - mean_absolute_error: 0.0424 - val_loss: 0.0342 - val_mean_absolute_error: 0.0500
# Epoch 277/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mean_absolute_error: 0.0380 - val_loss: 0.0292 - val_mean_absolute_error: 0.0539
# Epoch 278/1000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0071 - mean_absolute_error: 0.0346 - val_loss: 0.0249 - val_mean_absolute_error: 0.0471
#
# --- 모델 학습 완료 ---
#
# --- 테스트 데이터로 모델 성능을 평가합니다 ---
# 테스트 데이터 손실 (MSE): 0.0209
# 테스트 데이터 평균 절대 오차 (MAE): 0.0484
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 테스트 데이터 결정계수 (R²): 0.9771
# 최적의 epoch: 258
# 최소 val_loss: 0.02383
# === 최종 모델 성능 요약 ===
# 모델 구조: 8-32-16-1
# 활성화 함수: tanh
# 최적 epoch: 258
# 테스트 R²: 0.9771
# 테스트 MAE: 0.0484

# %% [markdown]
# 밑에는 과거 코드들
